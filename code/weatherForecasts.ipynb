# %%
# Dependencies
import json
import requests 
import pandas as pd
from time import ctime
from pprint import pprint

# %%
# Specify the URL
# Major cities in California

forecastCity = "Los Angeles"
dailyURL = "https://api.weather.gov/gridpoints/LOX/154,44/forecast"
hourlyURL = "https://api.weather.gov/gridpoints/LOX/154,44/forecast/hourly"

# %%
dailyResponse['properties']['periods']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b4606bf1b9f5> in <module>
# ----> 1 dailyResponse['properties']['periods']
#
# NameError: name 'dailyResponse' is not defined

# %%
# Make request and store response
dailyResponse = requests.get(dailyURL).json()
pprint(dailyResponse)
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#               {'@version': '1.1',
#                '@vocab': 'https://api.weather.gov/ontology#',
#                'geo': 'http://www.opengis.net/ont/geosparql#',
#                'unit': 'http://codes.wmo.int/common/unit/',
#                'wx': 'https://api.weather.gov/ontology#'}],
#  'geometry': {'coordinates': [[[-118.2618399, 34.062663],
#                                [-118.25719459999999, 34.0404501],
#                                [-118.23047399999999, 34.0442838],
#                                [-118.23511409999999, 34.0664973],
#                                [-118.2618399, 34.062663]]],
#               'type': 'Polygon'},
#  'properties': {'elevation': {'unitCode': 'wmoUnit:m', 'value': 114.9096},
#                 'forecastGenerator': 'BaselineForecastGenerator',
#                 'generatedAt': '2021-10-16T13:39:16+00:00',
#                 'periods': [{'detailedForecast': 'Sunny, with a high near 91. '
#                                                  'East northeast wind 5 to 10 '
#                                                  'mph.',
#                              'endTime': '2021-10-16T18:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=medium',
#                              'isDaytime': True,
#                              'name': 'Today',
#                              'number': 1,
#                              'shortForecast': 'Sunny',
#                              'startTime': '2021-10-16T06:00:00-07:00',
#                              'temperature': 91,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ENE',
#                              'windSpeed': '5 to 10 mph'},
#                             {'detailedForecast': 'Partly cloudy, with a low '
#                                                  'around 58. South southeast '
#                                                  'wind 0 to 5 mph.',
#                              'endTime': '2021-10-17T06:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#                              'isDaytime': False,
#                              'name': 'Tonight',
#                              'number': 2,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-16T18:00:00-07:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '0 to 5 mph'},
#                             {'detailedForecast': 'Mostly sunny, with a high '
#                                                  'near 76. South southeast '
#                                                  'wind 0 to 5 mph.',
#                              'endTime': '2021-10-17T18:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#                              'isDaytime': True,
#                              'name': 'Sunday',
#                              'number': 3,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T06:00:00-07:00',
#                              'temperature': 76,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '0 to 5 mph'},
#                             {'detailedForecast': 'Patchy drizzle and patchy '
#                                                  'fog after 11pm. Mostly '
#                                                  'cloudy, with a low around '
#                                                  '53. South southeast wind 0 '
#                                                  'to 5 mph.',
#                              'endTime': '2021-10-18T06:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain?size=medium',
#                              'isDaytime': False,
#                              'name': 'Sunday Night',
#                              'number': 4,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-17T18:00:00-07:00',
#                              'temperature': 53,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '0 to 5 mph'},
#                             {'detailedForecast': 'Patchy drizzle and patchy '
#                                                  'fog before 11am. Mostly '
#                                                  'cloudy, with a high near 67. '
#                                                  'South wind 5 to 10 mph.',
#                              'endTime': '2021-10-18T18:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain/bkn?size=medium',
#                              'isDaytime': True,
#                              'name': 'Monday',
#                              'number': 5,
#                              'shortForecast': 'Patchy Drizzle then Mostly '
#                                               'Cloudy',
#                              'startTime': '2021-10-18T06:00:00-07:00',
#                              'temperature': 67,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 to 10 mph'},
#                             {'detailedForecast': 'Patchy fog after 11pm. '
#                                                  'Mostly cloudy, with a low '
#                                                  'around 48.',
#                              'endTime': '2021-10-19T06:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/fog?size=medium',
#                              'isDaytime': False,
#                              'name': 'Monday Night',
#                              'number': 6,
#                              'shortForecast': 'Patchy Fog',
#                              'startTime': '2021-10-18T18:00:00-07:00',
#                              'temperature': 48,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '5 to 10 mph'},
#                             {'detailedForecast': 'Patchy fog before 11am. '
#                                                  'Mostly sunny, with a high '
#                                                  'near 70.',
#                              'endTime': '2021-10-19T18:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/fog/sct?size=medium',
#                              'isDaytime': True,
#                              'name': 'Tuesday',
#                              'number': 7,
#                              'shortForecast': 'Patchy Fog then Mostly Sunny',
#                              'startTime': '2021-10-19T06:00:00-07:00',
#                              'temperature': 70,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '5 to 10 mph'},
#                             {'detailedForecast': 'Partly cloudy, with a low '
#                                                  'around 52.',
#                              'endTime': '2021-10-20T06:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#                              'isDaytime': False,
#                              'name': 'Tuesday Night',
#                              'number': 8,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-19T18:00:00-07:00',
#                              'temperature': 52,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'WNW',
#                              'windSpeed': '0 to 10 mph'},
#                             {'detailedForecast': 'Mostly sunny, with a high '
#                                                  'near 72.',
#                              'endTime': '2021-10-20T18:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#                              'isDaytime': True,
#                              'name': 'Wednesday',
#                              'number': 9,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-20T06:00:00-07:00',
#                              'temperature': 72,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '5 to 10 mph'},
#                             {'detailedForecast': 'Partly cloudy, with a low '
#                                                  'around 54.',
#                              'endTime': '2021-10-21T06:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#                              'isDaytime': False,
#                              'name': 'Wednesday Night',
#                              'number': 10,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-20T18:00:00-07:00',
#                              'temperature': 54,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NNW',
#                              'windSpeed': '0 to 10 mph'},
#                             {'detailedForecast': 'Mostly sunny, with a high '
#                                                  'near 78.',
#                              'endTime': '2021-10-21T18:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#                              'isDaytime': True,
#                              'name': 'Thursday',
#                              'number': 11,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-21T06:00:00-07:00',
#                              'temperature': 78,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '5 to 10 mph'},
#                             {'detailedForecast': 'Partly cloudy, with a low '
#                                                  'around 55.',
#                              'endTime': '2021-10-22T06:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#                              'isDaytime': False,
#                              'name': 'Thursday Night',
#                              'number': 12,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-21T18:00:00-07:00',
#                              'temperature': 55,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '5 to 10 mph'},
#                             {'detailedForecast': 'Mostly sunny, with a high '
#                                                  'near 77.',
#                              'endTime': '2021-10-22T18:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#                              'isDaytime': True,
#                              'name': 'Friday',
#                              'number': 13,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T06:00:00-07:00',
#                              'temperature': 77,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'W',
#                              'windSpeed': '5 to 10 mph'},
#                             {'detailedForecast': 'Mostly cloudy, with a low '
#                                                  'around 54.',
#                              'endTime': '2021-10-23T06:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn?size=medium',
#                              'isDaytime': False,
#                              'name': 'Friday Night',
#                              'number': 14,
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2021-10-22T18:00:00-07:00',
#                              'temperature': 54,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '5 to 10 mph'}],
#                 'units': 'us',
#                 'updateTime': '2021-10-16T12:13:12+00:00',
#                 'updated': '2021-10-16T12:13:12+00:00',
#                 'validTimes': '2021-10-16T06:00:00+00:00/P7DT19H'},
#  'type': 'Feature'}

# %%
dailyForecasts = dailyResponse['properties']['periods']

for dailyForecast in dailyForecasts:
    print("-------------------------------")
    pprint(dailyForecast)
# Out:
# -------------------------------
# {'detailedForecast': 'Sunny, with a high near 91. East northeast wind 5 to 10 '
#                      'mph.',
#  'endTime': '2021-10-16T18:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/day/few?size=medium',
#  'isDaytime': True,
#  'name': 'Today',
#  'number': 1,
#  'shortForecast': 'Sunny',
#  'startTime': '2021-10-16T06:00:00-07:00',
#  'temperature': 91,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'ENE',
#  'windSpeed': '5 to 10 mph'}
# -------------------------------
# {'detailedForecast': 'Partly cloudy, with a low around 58. South southeast '
#                      'wind 0 to 5 mph.',
#  'endTime': '2021-10-17T06:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#  'isDaytime': False,
#  'name': 'Tonight',
#  'number': 2,
#  'shortForecast': 'Partly Cloudy',
#  'startTime': '2021-10-16T18:00:00-07:00',
#  'temperature': 58,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'SSE',
#  'windSpeed': '0 to 5 mph'}
# -------------------------------
# {'detailedForecast': 'Mostly sunny, with a high near 76. South southeast wind '
#                      '0 to 5 mph.',
#  'endTime': '2021-10-17T18:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#  'isDaytime': True,
#  'name': 'Sunday',
#  'number': 3,
#  'shortForecast': 'Mostly Sunny',
#  'startTime': '2021-10-17T06:00:00-07:00',
#  'temperature': 76,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'SSE',
#  'windSpeed': '0 to 5 mph'}
# -------------------------------
# {'detailedForecast': 'Patchy drizzle and patchy fog after 11pm. Mostly cloudy, '
#                      'with a low around 53. South southeast wind 0 to 5 mph.',
#  'endTime': '2021-10-18T06:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/night/rain?size=medium',
#  'isDaytime': False,
#  'name': 'Sunday Night',
#  'number': 4,
#  'shortForecast': 'Patchy Drizzle',
#  'startTime': '2021-10-17T18:00:00-07:00',
#  'temperature': 53,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'SSE',
#  'windSpeed': '0 to 5 mph'}
# -------------------------------
# {'detailedForecast': 'Patchy drizzle and patchy fog before 11am. Mostly '
#                      'cloudy, with a high near 67. South wind 5 to 10 mph.',
#  'endTime': '2021-10-18T18:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/day/rain/bkn?size=medium',
#  'isDaytime': True,
#  'name': 'Monday',
#  'number': 5,
#  'shortForecast': 'Patchy Drizzle then Mostly Cloudy',
#  'startTime': '2021-10-18T06:00:00-07:00',
#  'temperature': 67,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'S',
#  'windSpeed': '5 to 10 mph'}
# -------------------------------
# {'detailedForecast': 'Patchy fog after 11pm. Mostly cloudy, with a low around '
#                      '48.',
#  'endTime': '2021-10-19T06:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/night/fog?size=medium',
#  'isDaytime': False,
#  'name': 'Monday Night',
#  'number': 6,
#  'shortForecast': 'Patchy Fog',
#  'startTime': '2021-10-18T18:00:00-07:00',
#  'temperature': 48,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'SE',
#  'windSpeed': '5 to 10 mph'}
# -------------------------------
# {'detailedForecast': 'Patchy fog before 11am. Mostly sunny, with a high near '
#                      '70.',
#  'endTime': '2021-10-19T18:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/day/fog/sct?size=medium',
#  'isDaytime': True,
#  'name': 'Tuesday',
#  'number': 7,
#  'shortForecast': 'Patchy Fog then Mostly Sunny',
#  'startTime': '2021-10-19T06:00:00-07:00',
#  'temperature': 70,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'SSE',
#  'windSpeed': '5 to 10 mph'}
# -------------------------------
# {'detailedForecast': 'Partly cloudy, with a low around 52.',
#  'endTime': '2021-10-20T06:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#  'isDaytime': False,
#  'name': 'Tuesday Night',
#  'number': 8,
#  'shortForecast': 'Partly Cloudy',
#  'startTime': '2021-10-19T18:00:00-07:00',
#  'temperature': 52,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'WNW',
#  'windSpeed': '0 to 10 mph'}
# -------------------------------
# {'detailedForecast': 'Mostly sunny, with a high near 72.',
#  'endTime': '2021-10-20T18:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#  'isDaytime': True,
#  'name': 'Wednesday',
#  'number': 9,
#  'shortForecast': 'Mostly Sunny',
#  'startTime': '2021-10-20T06:00:00-07:00',
#  'temperature': 72,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'W',
#  'windSpeed': '5 to 10 mph'}
# -------------------------------
# {'detailedForecast': 'Partly cloudy, with a low around 54.',
#  'endTime': '2021-10-21T06:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#  'isDaytime': False,
#  'name': 'Wednesday Night',
#  'number': 10,
#  'shortForecast': 'Partly Cloudy',
#  'startTime': '2021-10-20T18:00:00-07:00',
#  'temperature': 54,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'NNW',
#  'windSpeed': '0 to 10 mph'}
# -------------------------------
# {'detailedForecast': 'Mostly sunny, with a high near 78.',
#  'endTime': '2021-10-21T18:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#  'isDaytime': True,
#  'name': 'Thursday',
#  'number': 11,
#  'shortForecast': 'Mostly Sunny',
#  'startTime': '2021-10-21T06:00:00-07:00',
#  'temperature': 78,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'W',
#  'windSpeed': '5 to 10 mph'}
# -------------------------------
# {'detailedForecast': 'Partly cloudy, with a low around 55.',
#  'endTime': '2021-10-22T06:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#  'isDaytime': False,
#  'name': 'Thursday Night',
#  'number': 12,
#  'shortForecast': 'Partly Cloudy',
#  'startTime': '2021-10-21T18:00:00-07:00',
#  'temperature': 55,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'N',
#  'windSpeed': '5 to 10 mph'}
# -------------------------------
# {'detailedForecast': 'Mostly sunny, with a high near 77.',
#  'endTime': '2021-10-22T18:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#  'isDaytime': True,
#  'name': 'Friday',
#  'number': 13,
#  'shortForecast': 'Mostly Sunny',
#  'startTime': '2021-10-22T06:00:00-07:00',
#  'temperature': 77,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'W',
#  'windSpeed': '5 to 10 mph'}
# -------------------------------
# {'detailedForecast': 'Mostly cloudy, with a low around 54.',
#  'endTime': '2021-10-23T06:00:00-07:00',
#  'icon': 'https://api.weather.gov/icons/land/night/bkn?size=medium',
#  'isDaytime': False,
#  'name': 'Friday Night',
#  'number': 14,
#  'shortForecast': 'Mostly Cloudy',
#  'startTime': '2021-10-22T18:00:00-07:00',
#  'temperature': 54,
#  'temperatureTrend': None,
#  'temperatureUnit': 'F',
#  'windDirection': 'SE',
#  'windSpeed': '5 to 10 mph'}

# %%
dailyForecast = dailyResponse['properties']['periods'][0]
# pprint(dailyForecast)
dailyForecast['city']= forecastCity
dailyForecast['runTime']= [ctime()]
dailyForecast
# Out:
# {'number': 1,
#  'name': 'Today',
#  'startTime': '2021-10-16T06:00:00-07:00',
#  'endTime': '2021-10-16T18:00:00-07:00',
#  'isDaytime': True,
#  'temperature': 91,
#  'temperatureUnit': 'F',
#  'temperatureTrend': None,
#  'windSpeed': '5 to 10 mph',
#  'windDirection': 'ENE',
#  'icon': 'https://api.weather.gov/icons/land/day/few?size=medium',
#  'shortForecast': 'Sunny',
#  'detailedForecast': 'Sunny, with a high near 91. East northeast wind 5 to 10 mph.',
#  'city': 'Los Angeles',
#  'runTime': ['Sat Oct 16 10:39:05 2021']}

# %%
# Make request and store response
hourlyResponse = requests.get(hourlyURL).json()
pprint(hourlyResponse)
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#               {'@version': '1.1',
#                '@vocab': 'https://api.weather.gov/ontology#',
#                'geo': 'http://www.opengis.net/ont/geosparql#',
#                'unit': 'http://codes.wmo.int/common/unit/',
#                'wx': 'https://api.weather.gov/ontology#'}],
#  'geometry': {'coordinates': [[[-118.2618399, 34.062663],
#                                [-118.25719459999999, 34.0404501],
#                                [-118.23047399999999, 34.0442838],
#                                [-118.23511409999999, 34.0664973],
#                                [-118.2618399, 34.062663]]],
#               'type': 'Polygon'},
#  'properties': {'elevation': {'unitCode': 'wmoUnit:m', 'value': 114.9096},
#                 'forecastGenerator': 'HourlyForecastGenerator',
#                 'generatedAt': '2021-10-16T17:39:07+00:00',
#                 'periods': [{'detailedForecast': '',
#                              'endTime': '2021-10-16T11:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 1,
#                              'shortForecast': 'Sunny',
#                              'startTime': '2021-10-16T10:00:00-07:00',
#                              'temperature': 79,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ESE',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T12:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 2,
#                              'shortForecast': 'Sunny',
#                              'startTime': '2021-10-16T11:00:00-07:00',
#                              'temperature': 84,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ENE',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T13:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 3,
#                              'shortForecast': 'Sunny',
#                              'startTime': '2021-10-16T12:00:00-07:00',
#                              'temperature': 87,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ENE',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T14:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 4,
#                              'shortForecast': 'Sunny',
#                              'startTime': '2021-10-16T13:00:00-07:00',
#                              'temperature': 90,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ENE',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T15:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 5,
#                              'shortForecast': 'Sunny',
#                              'startTime': '2021-10-16T14:00:00-07:00',
#                              'temperature': 91,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'WSW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T16:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 6,
#                              'shortForecast': 'Sunny',
#                              'startTime': '2021-10-16T15:00:00-07:00',
#                              'temperature': 90,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'WSW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T17:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 7,
#                              'shortForecast': 'Sunny',
#                              'startTime': '2021-10-16T16:00:00-07:00',
#                              'temperature': 88,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'WSW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T18:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 8,
#                              'shortForecast': 'Sunny',
#                              'startTime': '2021-10-16T17:00:00-07:00',
#                              'temperature': 86,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'WSW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T19:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 9,
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2021-10-16T18:00:00-07:00',
#                              'temperature': 80,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'WSW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T20:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 10,
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2021-10-16T19:00:00-07:00',
#                              'temperature': 74,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'WSW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T21:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 11,
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2021-10-16T20:00:00-07:00',
#                              'temperature': 71,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T22:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 12,
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2021-10-16T21:00:00-07:00',
#                              'temperature': 69,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-16T23:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 13,
#                              'shortForecast': 'Mostly Clear',
#                              'startTime': '2021-10-16T22:00:00-07:00',
#                              'temperature': 67,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T00:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 14,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-16T23:00:00-07:00',
#                              'temperature': 66,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ENE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T01:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 15,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-17T00:00:00-07:00',
#                              'temperature': 64,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ENE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T02:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 16,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-17T01:00:00-07:00',
#                              'temperature': 62,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ENE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T03:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 17,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-17T02:00:00-07:00',
#                              'temperature': 62,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ESE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T04:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 18,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-17T03:00:00-07:00',
#                              'temperature': 60,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ESE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T05:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 19,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-17T04:00:00-07:00',
#                              'temperature': 60,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ESE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T06:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 20,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-17T05:00:00-07:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ESE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T07:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 21,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T06:00:00-07:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ESE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T08:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 22,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T07:00:00-07:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ESE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T09:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 23,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T08:00:00-07:00',
#                              'temperature': 61,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T10:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 24,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T09:00:00-07:00',
#                              'temperature': 65,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T11:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 25,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T10:00:00-07:00',
#                              'temperature': 69,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T12:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 26,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T11:00:00-07:00',
#                              'temperature': 71,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T13:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 27,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T12:00:00-07:00',
#                              'temperature': 74,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T14:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 28,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T13:00:00-07:00',
#                              'temperature': 75,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T15:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 29,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T14:00:00-07:00',
#                              'temperature': 76,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T16:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 30,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T15:00:00-07:00',
#                              'temperature': 75,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T17:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 31,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T16:00:00-07:00',
#                              'temperature': 74,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T18:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 32,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-17T17:00:00-07:00',
#                              'temperature': 72,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T19:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 33,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-17T18:00:00-07:00',
#                              'temperature': 68,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T20:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 34,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-17T19:00:00-07:00',
#                              'temperature': 64,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T21:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 35,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-17T20:00:00-07:00',
#                              'temperature': 62,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T22:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 36,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-17T21:00:00-07:00',
#                              'temperature': 61,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-17T23:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 37,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-17T22:00:00-07:00',
#                              'temperature': 59,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T00:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 38,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-17T23:00:00-07:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T01:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 39,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-18T00:00:00-07:00',
#                              'temperature': 57,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T02:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 40,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-18T01:00:00-07:00',
#                              'temperature': 56,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T03:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 41,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-18T02:00:00-07:00',
#                              'temperature': 56,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T04:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 42,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-18T03:00:00-07:00',
#                              'temperature': 54,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T05:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 43,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-18T04:00:00-07:00',
#                              'temperature': 54,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '0 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T06:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/rain?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 44,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-18T05:00:00-07:00',
#                              'temperature': 54,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T07:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 45,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-18T06:00:00-07:00',
#                              'temperature': 53,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T08:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 46,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-18T07:00:00-07:00',
#                              'temperature': 53,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T09:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 47,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-18T08:00:00-07:00',
#                              'temperature': 55,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T10:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 48,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-18T09:00:00-07:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T11:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/rain?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 49,
#                              'shortForecast': 'Patchy Drizzle',
#                              'startTime': '2021-10-18T10:00:00-07:00',
#                              'temperature': 61,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T12:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 50,
#                              'shortForecast': 'Partly Sunny',
#                              'startTime': '2021-10-18T11:00:00-07:00',
#                              'temperature': 63,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T13:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 51,
#                              'shortForecast': 'Partly Sunny',
#                              'startTime': '2021-10-18T12:00:00-07:00',
#                              'temperature': 65,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T14:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 52,
#                              'shortForecast': 'Partly Sunny',
#                              'startTime': '2021-10-18T13:00:00-07:00',
#                              'temperature': 67,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T15:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 53,
#                              'shortForecast': 'Partly Sunny',
#                              'startTime': '2021-10-18T14:00:00-07:00',
#                              'temperature': 67,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T16:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 54,
#                              'shortForecast': 'Partly Sunny',
#                              'startTime': '2021-10-18T15:00:00-07:00',
#                              'temperature': 66,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T17:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 55,
#                              'shortForecast': 'Partly Sunny',
#                              'startTime': '2021-10-18T16:00:00-07:00',
#                              'temperature': 66,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T18:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 56,
#                              'shortForecast': 'Partly Sunny',
#                              'startTime': '2021-10-18T17:00:00-07:00',
#                              'temperature': 64,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T19:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 57,
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2021-10-18T18:00:00-07:00',
#                              'temperature': 61,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T20:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 58,
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2021-10-18T19:00:00-07:00',
#                              'temperature': 57,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T21:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 59,
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2021-10-18T20:00:00-07:00',
#                              'temperature': 56,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T22:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 60,
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2021-10-18T21:00:00-07:00',
#                              'temperature': 54,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-18T23:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 61,
#                              'shortForecast': 'Mostly Cloudy',
#                              'startTime': '2021-10-18T22:00:00-07:00',
#                              'temperature': 53,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'S',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-19T00:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/fog?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 62,
#                              'shortForecast': 'Patchy Fog',
#                              'startTime': '2021-10-18T23:00:00-07:00',
#                              'temperature': 52,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-19T01:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/fog?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 63,
#                              'shortForecast': 'Patchy Fog',
#                              'startTime': '2021-10-19T00:00:00-07:00',
#                              'temperature': 51,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-19T02:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/fog?size=small',
#                              'isDaytime': False,
#                              'name': '',
# ...
#                              'windDirection': 'ENE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T02:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 136,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-22T01:00:00-07:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'ENE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T03:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 137,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-22T02:00:00-07:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T04:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 138,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-22T03:00:00-07:00',
#                              'temperature': 56,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T05:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 139,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-22T04:00:00-07:00',
#                              'temperature': 56,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T06:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 140,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-22T05:00:00-07:00',
#                              'temperature': 56,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NNE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T07:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 141,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T06:00:00-07:00',
#                              'temperature': 55,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NNE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T08:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 142,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T07:00:00-07:00',
#                              'temperature': 55,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'NNE',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T09:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 143,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T08:00:00-07:00',
#                              'temperature': 58,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T10:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 144,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T09:00:00-07:00',
#                              'temperature': 63,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T11:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 145,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T10:00:00-07:00',
#                              'temperature': 68,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'N',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T12:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 146,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T11:00:00-07:00',
#                              'temperature': 71,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T13:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 147,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T12:00:00-07:00',
#                              'temperature': 74,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T14:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 148,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T13:00:00-07:00',
#                              'temperature': 76,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SSW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T15:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 149,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T14:00:00-07:00',
#                              'temperature': 77,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T16:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 150,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T15:00:00-07:00',
#                              'temperature': 76,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T17:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 151,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T16:00:00-07:00',
#                              'temperature': 75,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T18:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#                              'isDaytime': True,
#                              'name': '',
#                              'number': 152,
#                              'shortForecast': 'Mostly Sunny',
#                              'startTime': '2021-10-22T17:00:00-07:00',
#                              'temperature': 73,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'WSW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T19:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 153,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-22T18:00:00-07:00',
#                              'temperature': 69,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'WSW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T20:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 154,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-22T19:00:00-07:00',
#                              'temperature': 65,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'WSW',
#                              'windSpeed': '10 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T21:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 155,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-22T20:00:00-07:00',
#                              'temperature': 63,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '5 mph'},
#                             {'detailedForecast': '',
#                              'endTime': '2021-10-22T22:00:00-07:00',
#                              'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#                              'isDaytime': False,
#                              'name': '',
#                              'number': 156,
#                              'shortForecast': 'Partly Cloudy',
#                              'startTime': '2021-10-22T21:00:00-07:00',
#                              'temperature': 62,
#                              'temperatureTrend': None,
#                              'temperatureUnit': 'F',
#                              'windDirection': 'SW',
#                              'windSpeed': '5 mph'}],
#                 'units': 'us',
#                 'updateTime': '2021-10-16T12:13:12+00:00',
#                 'updated': '2021-10-16T12:13:12+00:00',
#                 'validTimes': '2021-10-16T06:00:00+00:00/P7DT19H'},
#  'type': 'Feature'}

# %%
hourlyForecast = hourlyResponse['properties']['periods'][0] 
# pprint(hourlyForecast)
hourlyForecast['city']= forecastCity
hourlyForecast['runTime']= [ctime()]
hourlyForecast
# Out:
# {'number': 1,
#  'name': '',
#  'startTime': '2021-10-14T19:00:00-07:00',
#  'endTime': '2021-10-14T20:00:00-07:00',
#  'isDaytime': False,
#  'temperature': 68,
#  'temperatureUnit': 'F',
#  'temperatureTrend': None,
#  'windSpeed': '10 mph',
#  'windDirection': 'WSW',
#  'icon': 'https://api.weather.gov/icons/land/night/skc?size=small',
#  'shortForecast': 'Clear',
#  'detailedForecast': '',
#  'city': 'Los Angeles',
#  'runTime': ['Thu Oct 14 20:19:14 2021']}

# %%
dailyForecastDF = pd.DataFrame.from_dict(dailyForecast)
dailyForecastDF = dailyForecastDF.rename(columns = {'number':"responseNumber",
                                                    'name':"responseName"})
dailyForecastDF
# Out:
#    responseNumber    responseName                  startTime  \
# 0               1  This Afternoon  2021-10-14T14:00:00-07:00
#
#                      endTime  isDaytime  temperature temperatureUnit  \
# 0  2021-10-14T18:00:00-07:00       True           79               F
#
#   temperatureTrend windSpeed windDirection  \
# 0             None    10 mph           WSW
#
#                                                 icon shortForecast  \
# 0  https://api.weather.gov/icons/land/day/skc?siz...         Sunny
#
#                                     detailedForecast         city  \
# 0  Sunny, with a high near 79. West southwest win...  Los Angeles
#
#                     runTime
# 0  Thu Oct 14 20:19:10 2021

# %%
hourlyForecastDF = pd.DataFrame.from_dict(hourlyForecast)
hourlyForecastDF = hourlyForecastDF.rename(columns = {'number':"responseNumber",
                                                    'name':"responseName"})
hourlyForecastDF
# Out:
#    responseNumber responseName                  startTime  \
# 0               1               2021-10-14T19:00:00-07:00
#
#                      endTime  isDaytime  temperature temperatureUnit  \
# 0  2021-10-14T20:00:00-07:00      False           68               F
#
#   temperatureTrend windSpeed windDirection  \
# 0             None    10 mph           WSW
#
#                                                 icon shortForecast  \
# 0  https://api.weather.gov/icons/land/night/skc?s...         Clear
#
#   detailedForecast         city                   runTime
# 0                   Los Angeles  Thu Oct 14 20:19:14 2021

# %%
from config import driver, username, password, host, port, database
from sqlalchemy import create_engine

# %%
connection_string = f"{driver}://{username}:{password}@{host}:{port}/{database}"
engine = create_engine(connection_string)
connection = engine.connect()

# %%
dailyForecastDF.to_sql('dailyForecastTB',connection, if_exists='append', index=False)
dailyForecastDF.head()
# Out:
#    responseNumber    responseName                  startTime  \
# 0               1  This Afternoon  2021-10-14T14:00:00-07:00
#
#                      endTime  isDaytime  temperature temperatureUnit  \
# 0  2021-10-14T18:00:00-07:00       True           79               F
#
#   temperatureTrend windSpeed windDirection  \
# 0             None    10 mph           WSW
#
#                                                 icon shortForecast  \
# 0  https://api.weather.gov/icons/land/day/skc?siz...         Sunny
#
#                                     detailedForecast         city  \
# 0  Sunny, with a high near 79. West southwest win...  Los Angeles
#
#                     runTime
# 0  Thu Oct 14 20:19:10 2021

# %%
import pandas as pd
historicDailyForecastDF = pd.read_sql_table('dailyForecastTB', connection)
historicDailyForecastDF
# Out:
#    id responseNumber responseName         city  latitude  longitude  \
# 0   1           None         None  Los Angeles   94032.0  3902489.0
#
#   startDateTime startDate startTime endDateTime  ... temperatureTrend  \
# 0           NaT       NaT      None         NaT  ...             None
#
#   windSpeed minWindSpeed maxWindSpeed windSpeedUnit windDirection  icon  \
# 0      None         None         None          None          None  None
#
#   shortForecast detailedForecast retrievalDateTime
# 0          None             None               NaT
#
# [1 rows x 25 columns]

# %%
hourlyForecastDF.to_sql('hourlyForecastTB',connection, if_exists='append', index=False)
hourlyForecastDF.head()
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# UndefinedColumn: column "id" of relation "histHourlyForecastTB" does not exist
# LINE 1: INSERT INTO "histHourlyForecastTB"("id", "city", "responseNu...
#                                            ^
# QUERY:  INSERT INTO "histHourlyForecastTB"("id", "city", "responseNumber", "responseName", "startTime", "endTime",
# 									   "isDaytime", "temperature", "temperatureUnit", "temperatureTrend", "windSpeed",
# 									   "windDirection", "icon", "shortForecast", "detailedForecast", "runTime")
# 	 VALUES(NEW."id" , NEW."city", NEW."responseNumber", NEW."responseName", NEW."startTime", NEW."endTime",
# 			NEW."isDaytime", NEW."temperature", NEW."temperatureUnit", NEW."temperatureTrend", NEW."windSpeed",
# 			NEW."windDirection", NEW."icon", NEW."shortForecast", NEW."detailedForecast", NEW."runTime")
# CONTEXT:  PL/pgSQL function loghourlyforecastchanges() line 3 at SQL statement
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-61-a6f075241d65> in <module>
# ----> 1 hourlyForecastDF.to_sql('hourlyForecastTB',connection, if_exists='append', index=False)
#       2 hourlyForecastDF.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2867         from pandas.io import sql
#    2868
# -> 2869         sql.to_sql(
#    2870             self,
#    2871             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1198             )
#    1199         else:
# -> 1200             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1201
#    1202     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1387             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388         )
# -> 1389         ret = self._execute_context(
#    1390             dialect,
#    1391             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1703                             break
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#    1707                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     690
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#     694     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "id" of relation "histHourlyForecastTB" does not exist
# LINE 1: INSERT INTO "histHourlyForecastTB"("id", "city", "responseNu...
#                                            ^
# QUERY:  INSERT INTO "histHourlyForecastTB"("id", "city", "responseNumber", "responseName", "startTime", "endTime",
# 									   "isDaytime", "temperature", "temperatureUnit", "temperatureTrend", "windSpeed",
# 									   "windDirection", "icon", "shortForecast", "detailedForecast", "runTime")
# 	 VALUES(NEW."id" , NEW."city", NEW."responseNumber", NEW."responseName", NEW."startTime", NEW."endTime",
# 			NEW."isDaytime", NEW."temperature", NEW."temperatureUnit", NEW."temperatureTrend", NEW."windSpeed",
# 			NEW."windDirection", NEW."icon", NEW."shortForecast", NEW."detailedForecast", NEW."runTime")
# CONTEXT:  PL/pgSQL function loghourlyforecastchanges() line 3 at SQL statement
#
# [SQL: INSERT INTO "hourlyForecastTB" ("responseNumber", "responseName", "startTime", "endTime", "isDaytime", temperature, "temperatureUnit", "temperatureTrend", "windSpeed", "windDirection", icon, "shortForecast", "detailedForecast", city, "runTime") VALUES (%(responseNumber)s, %(responseName)s, %(startTime)s, %(endTime)s, %(isDaytime)s, %(temperature)s, %(temperatureUnit)s, %(temperatureTrend)s, %(windSpeed)s, %(windDirection)s, %(icon)s, %(shortForecast)s, %(detailedForecast)s, %(city)s, %(runTime)s)]
# [parameters: {'responseNumber': 1, 'responseName': '', 'startTime': '2021-10-14T19:00:00-07:00', 'endTime': '2021-10-14T20:00:00-07:00', 'isDaytime': False, 'temperature': 68, 'temperatureUnit': 'F', 'temperatureTrend': None, 'windSpeed': '10 mph', 'windDirection': 'WSW', 'icon': 'https://api.weather.gov/icons/land/night/skc?size=small', 'shortForecast': 'Clear', 'detailedForecast': '', 'city': 'Los Angeles', 'runTime': 'Thu Oct 14 20:19:14 2021'}]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
historicHourlyForecastDF = pd.read_sql_table('hourlyForecastTB', connection)
historicHourlyForecastDF

# %%
pd.options.display.max_columns = 30

# %%
from slack_config import webhookURL

# %%
import json
import sys
import random
import requests
if __name__ == '__main__':
    message = ("Here's the weather for Alan!")
#     title = (f"New Incoming Emoji")
    slack_data = {
        "username": "TyphoonsTuesday",
        "icon_emoji": ":tornado:",
        "channel" : "#general",
        "attachments": [
            {
                "color": "#9733EE",
                "fields": [
                    {
#                         "title": title,
                        "value": message,
                        "short": "false",
                    }
                ]
            }
        ]
    }
    byte_length = str(sys.getsizeof(slack_data))
    headers = {'Content-Type': "application/json", 'Content-Length': byte_length}
    response = requests.post(webhookURL, data=json.dumps(slack_data), headers=headers)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
