# %%
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
#################################################
# Database Setup
#################################################
engine = create_engine("sqlite:///data/titanic.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save reference to the table
Passenger = Base.classes.passenger

# %% [markdown]
# ## Query Passenger Names

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
# Query all passengers
results = session.query(Passenger.name).all()

# %%
session.close()

# %%
list(results)[:10]
# Out:
# [('Allen, Miss Elisabeth Walton'),
#  ('Allison, Miss Helen Loraine'),
#  ('Allison, Mr Hudson Joshua Creighton'),
#  ('Allison, Mrs Hudson JC (Bessie Waldo Daniels)'),
#  ('Allison, Master Hudson Trevor'),
#  ('Anderson, Mr Harry'),
#  ('Andrews, Miss Kornelia Theodosia'),
#  ('Andrews, Mr Thomas, jr'),
#  ('Appleton, Mrs Edward Dale (Charlotte Lamson)'),
#  ('Artagaveytia, Mr Ramon')]

# %%
# Convert list of tuples into normal list
all_names = [name[0] for name in results]
all_names
# Out:
# ['Allen, Miss Elisabeth Walton',
#  'Allison, Miss Helen Loraine',
#  'Allison, Mr Hudson Joshua Creighton',
#  'Allison, Mrs Hudson JC (Bessie Waldo Daniels)',
#  'Allison, Master Hudson Trevor',
#  'Anderson, Mr Harry',
#  'Andrews, Miss Kornelia Theodosia',
#  'Andrews, Mr Thomas, jr',
#  'Appleton, Mrs Edward Dale (Charlotte Lamson)',
#  'Artagaveytia, Mr Ramon',
#  'Astor, Colonel John Jacob',
#  'Astor, Mrs John Jacob (Madeleine Talmadge Force)',
#  'Aubert, Mrs Leontine Pauline',
#  'Barkworth, Mr Algernon H',
#  'Baumann, Mr John D',
#  'Baxter, Mrs James (Helene DeLaudeniere Chaput)',
#  'Baxter, Mr Quigg Edmond',
#  'Beattie, Mr Thomson',
#  'Beckwith, Mr Richard Leonard',
#  'Beckwith, Mrs Richard Leonard (Sallie Monypeny)',
#  'Behr, Mr Karl Howell',
#  'Birnbaum, Mr Jakob',
#  'Bishop, Mr Dickinson H',
#  'Bishop, Mrs Dickinson H (Helen Walton)',
#  'Bjornstrm-Steffansson, Mr Mauritz Hakan',
#  'Blackwell, Mr Stephen Weart',
#  'Blank, Mr Henry',
#  'Bonnell, Miss Caroline',
#  'Bonnell, Miss Elizabeth',
#  'Borebank, Mr John James',
#  'Bowen, Miss Grace Scott',
#  'Bowerman, Miss Elsie Edith',
#  'Bradley, Mr George',
#  'Brady, Mr John Bertram',
#  'Brandeis, Mr Emil',
#  'Brewe, Dr Arthur Jackson',
#  'Brown, Mrs James Joseph (Margaret Molly" Tobin)"',
#  'Brown, Mrs John Murray (Caroline Lane Lamson)',
#  'Bucknell, Mrs William Robert (Emma Eliza Ward)',
#  'Butt, Major Archibald Willingham',
#  'Calderhead, Mr Edward P',
#  'Candee, Mrs Edward (Helen Churchill Hungerford)',
#  'Cardeza, Mrs James Warburton Martinez (Charlotte Wardle Drake)',
#  'Cardeza, Mr Thomas Drake Martinez',
#  'Carlsson, Mr Frans Olof',
#  'Carrau, Mr Francisco M',
#  'Carrau, Mr Jose Pedro',
#  'Carter, Mr William Ernest',
#  'Carter, Mrs William Ernest (Lucile Polk)',
#  'Carter, Miss Lucile Polk',
#  'Carter, Master William T II',
#  'Case, Mr Howard Brown',
#  'Cassebeer, Mrs Henry Arthur jr (Genevieve Fosdick)',
#  'Cavendish, Mr Tyrell William',
#  'Cavendish, Mrs Tyrell William Julia Florence Siegel',
#  'Chaffee, Mr Herbert Fuller',
#  'Chaffee, Mrs Herbert Fuller (Carrie Constance Toogood)',
#  'Chambers, Mr Norman Campbell',
#  'Chambers, Mrs Norman Campbell (Bertha Griggs)',
#  'Cherry, Miss Gladys',
#  'Chevre, Mr Paul',
#  'Chibnall (Bowerman), Mrs Edith Martha',
#  'Chisholm, Mr Roderick Robert',
#  'Clark, Mr Walter Miller',
#  'Clark, Mrs Walter Miller (Virginia McDowell)',
#  'Clifford, Mr George Quincy',
#  'Colley, Mr Edward Pomeroy',
#  'Compton, Mrs Alexander Taylor (Mary Eliza Ingersoll)',
#  'Compton, Mr Alexander Taylor, Jr',
#  'Compton, Miss Sara Rebecca',
#  'Cornell, Mrs Robert Clifford (Malvina Helen Lamson)',
#  'Crafton, Mr John Bertram',
#  'Crosby, Captain Edward Gifford',
#  'Crosby, Mrs Edward Gifford (Catherine Elizabeth Halstead)',
#  'Crosby, Miss Harriet R',
#  'Cumings, Mr John Bradley',
#  'Cumings, Mrs John Bradley (Florence Briggs Thayer)',
#  'Daly, Mr Peter Denis ',
#  'Daniel, Mr Robert Williams',
#  'Davidson, Mr Thornton',
#  'Davidson, Mrs Thornton (Orian Hays)',
#  'de Villiers, Madame Berthe',
#  'Dick, Mr Albert Adrian',
#  'Dick, Mrs Albert Adrian Vera Gillespie',
#  'Dodge, Dr Washington',
#  'Dodge, Mrs Washington (Ruth Vidaver)',
#  'Dodge, Master Washington',
#  'Douglas, Mrs Frederick Charles (Suzette Baxter)',
#  'Douglas, Mr Walter Donald',
#  'Douglas, Mrs Walter Donald (Mahala Dutton)',
#  'Duff Gordon, Sir Cosmo Edmund',
#  'Duff Gordon, Lady (Lucille Wallace Sutherland)',
#  'Dulles, Mr William Crothers',
#  'Earnshaw, Mrs Boulton (Olive Potter)',
#  'Eustis, Miss Elizabeth Mussey',
#  'Evans, Miss Edith Corse',
#  'Flegenheim, Mrs Alfred (Antoinette)',
#  'Flynn, Mr John Irving',
#  'Foreman, Mr Benjamin Laventall',
#  'Fortune, Miss Alice Elizabeth',
#  'Fortune, Mr Charles Alexander',
#  'Fortune, Miss Ethel Flora',
#  'Fortune, Miss Mabel',
#  'Fortune, Mr Mark',
#  'Fortune, Mrs Mark (Mary McDougald)',
#  'Franklin, Mr Thomas Parham',
#  'Frauenthal, Dr Henry William',
#  'Frauenthal, Mrs Henry William (Clara Heinsheimer)',
#  'Frauenthal, Mr Isaac Gerald',
#  'Frolicher, Miss Marguerite',
#  'Frolicher-Stehli, Mr Maxmillian',
#  'Frolicher-Stehli, Mrs Maxmillian (Margaretha Emerentia Stehli)',
#  'Futrelle, Mr Jacques',
#  'Futrelle, Mrs Jacques (May Peel)',
#  'Gee, Mr Arthur H',
#  'Gibson, Miss Dorothy',
#  'Gibson, Mrs Leonard (Pauline C Boeson)',
#  'Goldenberg, Mr Samuel L',
#  'Goldenberg, Mrs Samuel L (Edwiga Grabowsko)',
#  'Goldschmidt, Mr George B',
#  'Gracie, Colonel Archibald IV',
#  'Graham, Mr George Edward',
#  'Graham, Miss Margaret Edith',
#  'Graham, Mrs William Thompson (Edith Junkins)',
#  'Greenfield, Mrs Leo David (Blanche Strouse)',
#  'Greenfield, Mr William Bertram',
#  'Guggenheim, Mr Benjamin',
#  'Harder, Mr George Achilles',
#  'Harder, Mrs George Achilles (Dorothy Annan)',
#  'Harper, Mr Henry Sleeper',
#  'Harper, Mrs Henry Sleeper (Myna Haxtun)',
#  'Harris, Mr Henry Birkhardt',
#  'Harris, Mrs Henry Birkhardt (Irene Wallach)',
#  'Hawksford, Mr Walter James',
#  'Hays, Mr Charles Melville',
#  'Hays, Mrs Charles Melville (Clara Jennings Gregg)',
#  'Hays, Miss Margaret Bechstein',
#  'Head, Mr Christopher',
#  'Hilliard, Mr Herbert Henry',
#  'Hipkins, Mr William Edward',
#  'Hippach, Miss Jean Gertrude',
#  'Hippach, Mrs Louis Albert (Ida Sophia Fischer)',
#  'Hogeboom, Mrs John C (Anna Andrews)',
#  'Holverson, Mr Alexander Oskar',
#  'Holverson, Mrs Alexander Oskar (Mary Aline Towner)',
#  'Homer, Mr Harry',
#  'Hoyt, Mr Frederick Maxfield',
#  'Hoyt, Mrs Frederick Maxfield (Jane Anne Forby)',
#  'Hoyt, Mr William F',
#  'Isham, Miss Anne Elizabeth',
#  'Ismay, Mr Joseph Bruce',
#  'Jones, Mr Charles Cresson',
#  'Julian, Mr Henry Forbes',
#  'Kent, Mr Edward Austin',
#  'Kenyon, Mr Frederick R',
#  'Kenyon, Mrs Frederick R (Marion)',
#  'Kimball, Mr Edwin Nelson Jr',
#  'Kimball, Mrs Edwin Nelson Jr (Gertrude Parsons)',
#  'Klaber, Mr Herman',
#  'Leader, Dr Alice Farnham',
#  'Lewy, Mr Ervin G',
#  'Lindeberg-Lind, Mr Erik Gustaf',
#  'Lindstrom, Mrs Carl Johan (Sigrid Posse)',
#  'Lines, Mrs Ernest H (Elizabeth Lindsey James)',
#  'Lines, Miss Mary Conover',
#  'Lingrey, Mr Edward',
#  'Long, Mr Milton Clyde',
#  'Longley, Miss Gretchen Fiske',
#  'Loring, Mr Joseph Holland',
#  'Madill, Miss Georgette Alexandra',
#  'Maguire, Mr John Edward',
#  'Marechal, Mr Pierre',
#  'Marvin, Mr Daniel Warner',
#  'Marvin, Mrs Daniel Warner (Mary Graham Carmichael Farquarson)',
#  'McCaffry, Mr Thomas Francis',
#  'McCarthy, Mr Timothy J',
#  'McGough, Mr James R',
#  'Meyer, Mr Edgar Joseph',
#  'Meyer, Mrs Edgar Joseph (Leila Saks)',
#  'Millet, Mr Francis Davis',
#  'Minahan, Miss Daisy E',
#  'Minahan, Dr William Edward',
#  'Minahan, Mrs William Edward (Lillian E Thorpe)',
#  'Mock, Mr Philip E',
#  'Molson, Mr Harry Markland',
#  'Moore, Mr Clarence Bloomfield',
#  'Natsch, Mr Charles H',
#  'Newell, Mr Arthur Webster',
#  'Newell, Miss Madeleine',
#  'Newell, Miss Marjorie',
#  'Newsom, Miss Helen Monypeny',
#  'Nicholson, Mr Arthur Ernest',
#  'Omont, Mr A Fernand',
#  'Ostby, Mr Engelhart Cornelius',
#  'Ostby, Miss Helen Raghnild',
#  'Ovies y Rodriguez, Mr Servando',
#  'Parr, Mr William Henry Marsh',
#  'Partner, Mr Austin',
#  'Payne, Mr Vivian Ponsonby',
#  'Pears, Mr Thomas',
#  'Pears, Mrs Thomas (Edith)',
#  'Penasco, Mr Victor de Satode',
#  'Penasco, Mrs Victor de Satode (Josefa de Soto)',
#  'Peuchen, Major Arthur Godfrey',
#  'Porter, Mr Walter Chamberlain',
#  'Potter, Mrs Thomas, Jr (Lily Alexenia Wilson)',
#  'Reuchlin, Jonkheer John George',
#  'Rheims, Mr George Lucien',
#  'Robert, Mrs Edward Scott (Elisabeth Walton McMillan)',
#  'Roebling, Mr Washington Augustus 2nd',
#  'Romaine, Mr Charles Hallace',
#  'Rood, Mr Hugh R',
#  'Rosenbaum (Russell), Miss Edith Louise',
#  'Ross, Mr John Hugo',
#  'Rothes, the Countess of (Noel Lucy Martha Dyer-Edwardes)',
#  'Rothschild, Mr Martin',
#  'Rothschild, Mrs Martin (Elizabeth L Barrett)',
#  'Rowe, Mr Alfred G',
#  'Ryerson, Mr Arthur Larned',
#  'Ryerson, Mrs Arthur Larned (Emily Maria Borie)',
#  'Ryerson, Miss Emily Borie',
#  'Ryerson, Master John Borie',
#  'Ryerson, Miss Susan (Suzette) Parker',
#  'Saalfeld, Mr Adolphe',
#  'Salomon, Mr Abraham L',
#  'Schabert, Mrs Paul (Emma Mock)',
#  'Seward, Mr Frederic Kimber',
#  'Shutes, Miss Elizabeth W',
#  'Silverthorne, Mr Spencer Victor',
#  'Silvey, Mr William Baird',
#  'Silvey, Mrs William Baird (Alice Munger)',
#  'Simonius-Blumer, Col Alfons',
#  'Sloper, Mr William Thompson',
#  'Smart, Mr John Montgomery',
#  'Smith, Mr James Clinch',
#  'Smith, Mr Lucien Philip',
#  'Smith, Mrs Lucien Philip (Mary Eloise Hughes',
#  'Smith, Mr Richard William',
#  'Snyder, Mr John Pillsbury',
#  'Snyder, Mrs John Pillsbury (Nelle Stevenson)',
#  'Spedden, Mr Frederick Oakley',
#  'Spedden, Mrs Frederick Oakley (Margaretta Corning Stone)',
#  'Spedden, Master Robert Douglas',
#  'Spencer, Mr William Augustus',
#  'Spencer, Mrs William Augustus (Marie Eugenie)',
#  'Staehlin, Dr Max',
#  'Stead, Mr William Thomas',
#  'Stengel, Mr Charles Emil Henry',
#  'Stengel, Mrs Charles Emil Henry (Annie May Morris)',
#  'Stephenson, Mrs Walter Bertram (Martha Eustis)',
#  'Stewart, Mr Albert A',
#  'Stone, Mrs George Nelson (Martha E)',
#  'Straus, Mr Isidor',
#  'Straus, Mrs Isidor (Ida Blun)',
#  'Sutton, Mr Frederick',
#  'Swift, Mrs Frederick Joel (Margaret Welles Barron)',
#  'Taussig, Mr Emil',
#  'Taussig, Mrs Emil (Tillie Mandelbaum)',
#  'Taussig, Miss Ruth',
#  'Taylor, Mr Elmer Zebley',
#  'Taylor, Mrs Elmer Zebley (Juliet Cummins Wright)',
#  'Thayer, Mr John Borland',
#  'Thayer, Mrs John Borland (Marian Longstreth Morris)',
#  'Thayer, Mr John Borland, jr',
#  'Thorne, Mr George (alias of: Mr George Rosenshine)',
#  'Thorne, Mrs Gertrude Maybelle',
#  'Tucker, Mr Gilbert Milligan, jr',
#  'Uruchurtu, Mr Manuel E',
#  'Van Derhoef, Mr Wyckoff',
#  'Walker, Mr William Anderson',
#  'Warren, Mr Frank Manley',
#  'Warren, Mrs Frank Manley (Anna S Atkinson)',
#  'Weir, Col John',
#  'White, Mrs J Stuart (Ella Holmes)',
#  'White, Mr Percival Wayland',
#  'White, Mr Richard Frasar',
#  'Wick, Mr George Dennick',
#  'Wick, Mrs George Dennick (Martha Hitchcock)',
#  'Wick, Miss Mary Natalie',
#  'Widener, Mr George Dunton',
#  'Widener, Mrs George Dunton (Eleanor Elkins)',
#  'Widener, Mr Harry Elkins',
#  'Willard, Miss Constance',
#  'Williams, Mr Charles Duane',
#  'Williams, Mr Fletcher Lambert',
#  'Williams, Mr Richard Norris II',
#  'Woolner, Mr Hugh',
#  'Wright, Mr George',
#  'Young, Miss Marie Grice',
#  'Barber, Ms ',
#  'Bazzani, Ms Albina',
#  'Bidois, Miss Rosalie',
#  'Bird, Ms Ellen',
#  'Bissetti, Ms Amelia',
#  'Burns, Ms Elizabeth Margaret',
#  'Chaudanson, Ms \tVictorine',
#  'Cleaver, Ms Alice',
#  'Daniels, Ms Sarah',
#  'Endres, Miss Caroline Louise',
#  'Farthing, Mr John',
#  'Fleming, Ms Margaret',
#  'Francatelli, Ms Laura Mabel',
#  'Fry, Mr Richard',
#  'Geiger, Miss Emily ',
#  'Giglio, Mr Victor',
#  'Harrington, Mr Charles',
#  'Harrison, Mr William \tHenry',
#  'Hassah, Mr Hamad',
#  'Icabad (Icabod), Ms',
#  'Keeping, Mr Edwin',
#  'Kenchen, Ms Amelia',
#  'LeRoy, Miss Berthe',
#  'Lesneur, Mr Gustave',
#  'Maloney, Ms',
#  'Oliva, Mlle',
#  'Pericault, Ms',
#  'Ringhini, Mr Sante',
#  'Robbins, Mr Victor',
#  'Segesser, Mlle Emma',
#  'Seredeca, Ms',
#  'Ward, Ms Anna',
#  'Wilson, Ms Helen',
#  'Abelson, Mr Samuel',
#  'Abelson, Mrs Samuel (Anna)',
#  'Andrew, Mr Edgar Samuel',
#  'Andrew, Mr Frank',
#  'Angle, Mr William A',
#  'Angle, Mrs William A (Florence)',
#  'Ashby, Mr John',
#  'Bailey, Mr Percy Andrew',
#  'Baimbrigge, Mr Charles R',
#  'Balls, Mrs Ada E Hall',
#  'Banfield, Mr Frederick J',
#  'Bateman, Rev Robert James',
#  'Beane, Mr Edward',
#  'Beane, Mrs Edward (Ethel Clarke)',
#  'Beauchamp, Mr Henry James',
#  'Becker, Mrs Allen Oliver (Nellie E Baumgardner)',
#  'Becker, Miss Marion Louise',
#  'Becker, Master Richard F',
#  'Becker, Miss Ruth Elizabeth',
#  'Beesley, Mr Lawrence',
#  'Bentham, Miss Lilian W',
#  'Berriman, Mr William S',
#  'Botsford, Mr William Hull',
#  'Bowenur, Mr Solomon',
#  'Bracken, Mr James H',
#  'Brown, Miss Edith E',
#  'Brown, Mr Thomas William Solomon',
#  'Brown, Mrs Thomas William Solomon (Elizabeth C)',
#  'Bryhl, Miss Dagmar',
#  'Bryhl, Mr Kurt Arnold Gottfrid',
#  'Buss, Miss Kate',
#  'Butler, Mr Reginald Fenton',
#  'Byles, Rev Thomas Roussel D',
#  'Bystrom, Mrs Carolina',
#  'Caldwell, Mr Albert Francis',
#  'Caldwell, Mrs Albert Francis (Sylvia Mae Harbaugh)',
#  'Caldwell, Master Alden Gates',
#  'Cameron, Miss Clear',
#  'Campbell, Mr William',
#  'Carbines, Mr William',
#  'Carter, Rev Ernest Courtenay',
#  'Carter, Mrs Ernest Courtenay (Lillian Hughes)',
#  'Chapman, Mr Charles Henry',
#  'Chapman, Mr John Henry',
#  'Chapman, Mrs John Henry (Elizabeth Lawry)',
#  'Christy, Mrs Alice Frances',
#  'Christy, Miss Julie',
#  'Clarke, Mr Charles V',
#  'Clarke, Mrs Charles V (Ada Maria)',
#  'Coleridge, Mr Reginald Charles',
#  'Collander, Mr Erik',
#  'Collett, Mr Sidney C Stuart',
#  'Collyer, Mr Harvey',
#  'Collyer, Mrs Harvey (Charlotte Tate)',
#  'Collyer, Miss Marjorie',
#  'Cook, Mrs Selena Rogers',
#  'Corbett, Mrs Walter H (Irene Colvin)',
#  'Corey, Mrs Percy C (Mary Phyllis Elizabeth Miller)',
#  'Cotterill, Mr Harry',
#  'Cunningham, Mr Alfred Fleming',
#  'Davies, Mr Charles Henry',
#  'Davis, Mrs Agnes',
#  'Davis, Master John Morgan',
#  'Davis, Miss Mary',
#  'Deacon, Mr Percy',
#  'de Brito, Mr Jose Joaquim',
#  'del Carlo, Mr Sebastiano',
#  'del Carlo, Mrs Sebastiano (Argenia Genovese)',
#  'Denbury, Mr Herbert',
#  'Dibden, Mr William',
#  'Doling, Mrs Ada',
#  'Doling, Miss Elsie',
#  'Downton (?Douton), Mr William James',
#  'Drew, Mr James Vivian',
#  'Drew, Mrs James Vivian (Lulu Thorne Christian)',
#  'Drew, Master Marshall Brines',
#  'Duran y More, Miss Asuncion',
#  'Duran y More, Miss Florentina',
#  'Eitemiller, Mr George Floyd',
#  'Enander, Mr Ingvar',
#  'Fahlstrom, Mr Arne Jonas',
#  'Faunthorpe, Mr Harry',
#  'Faunthorpe, Mrs Lizzie (see Wilkinson, E)',
#  'Fillbrook, Mr Charles',
#  'Fox, Mr Stanley H',
#  'Frost, Mr Anthony (Archie) W',
#  'Funk, Miss Annie C',
#  'Fynney, Mr Joseph J',
#  'Gale, Mr Harry',
#  'Gale, Mr Shadrach',
#  'Garside, Miss Ethel',
#  'Gaskell, Mr Alfred',
#  'Gavey, Mr Lawrence',
#  'Gilbert, Mr William',
#  'Giles, Mr Edgar',
#  'Giles, Mr Frederick',
#  'Giles, Mr Ralph',
#  'Gill, Mr John W',
#  'Gillespie, Mr William',
#  'Givard, Mr Hans Christensen',
#  'Greenberg, Mr Samuel',
#  'Hale, Mr Reginald',
#  'Hamalainen, Mrs William (Anna)',
#  'Hamalainen, Master Viljo',
#  'Harbeck, Mr William H',
#  'Harper, Rev John',
#  'Harper, Miss Nina',
#  'Harris, Mr George',
#  'Harris, Mr Walter',
#  'Hart, Mr Benjamin',
#  'Hart, Mrs Benjamin (Esther)',
#  'Hart, Miss Eva Miriam',
#  'Herman, Miss Alice',
#  'Herman, Miss Kate',
#  'Herman, Mr Samuel',
#  'Herman, Mrs Samuel (Jane Laver)',
#  'Hewlett, Mrs Mary D',
#  'Hickman, Mr Leonard Mark',
#  'Hickman, Mr Lewis',
#  'Hickman, Mr Stanley George',
#  'Hiltunen, Miss Marta',
#  'Hocking, Mrs Elizabeth',
#  'Hocking, Mr George',
#  'Hocking, Miss Ellen (Nellie)',
#  'Hocking, Mr Samuel James',
#  'Hodges, Mr Henry Price',
#  'Hold, Mr Stephen',
#  'Hold, Mrs Stephen (Annie Margaret)',
#  'Hood, Mr Ambrose, Jr',
#  'Hosono, Mr Masafumi',
#  'Howard, Mr Benjamin',
#  'Howard, Mrs Benjamin (Ellen Truelove)',
#  'Hunt, Mr George Henry',
#  'Ilett, Miss Bertha',
#  'Jacobsohn Mr Sidney Samuel',
#  'Jacobsohn, Mrs Sidney Samuel (Amy Frances Christy)',
#  'Jarvis, Mr John Denzil',
#  'Jefferys, Mr Clifford',
#  'Jefferys, Mr Ernest',
#  'Jenkin, Mr Stephen Curnow',
#  'Jerwan, Mrs Amin S (Marie Thuillard)',
#  'Kantor, Mr Sinai',
#  'Kantor, Mrs Sinai (Miriam Sternim)',
#  'Karnes, Mrs J Frank (Claire Bennett)',
#  'Keane, Mr Daniel',
#  'Keane, Miss Nora A',
#  'Kelly, Mrs Florence (Fannie)',
#  'Kirkland, Rev Charles Leonard',
#  'Knight, Mr Robert',
#  'Kvillner, Mr Johan Henrik Johannesson',
#  'Lahtinen, Rev William',
#  'Lahtinen, Mrs William (Anna Sylvan)',
#  'Lamb, Mr John James',
#  'Lemore, Mrs Amelia',
#  'LaRoche, Mr Joseph',
#  'LaRoche, Mrs Joseph (Juliet)',
#  'LaRoche, Miss Louise',
#  'LaRoche, Miss Simonne',
#  'Lehmann, Miss Bertha',
#  'Leitch, Miss Jessie',
#  'Levy, Mr Rene Jacques',
#  'Leyson, Mr Robert William Norman',
#  'Lingan, Mr John',
#  'Louch, Mr Charles Alexander',
#  'Louch, Mrs Charles Alexander (Alice Adelaide)',
#  'Mack, Mrs Mary',
#  'Malachard, Mr Noel',
#  'Mallet, Mr Albert',
#  'Mallet, Mrs Albert (Antoinette)',
#  'Mallet, Master Andre',
#  'Mangiavacchi, Mr Serafino Emilio',
#  'Mantvila, Rev Joseph',
#  'Marshall, Mrs Kate Louise Phillips',
#  'Matthews, Mr William John',
#  'Maybery, Mr Frank H',
#  'McCrae, Mr Arthur Gordon',
#  'McCrie, Mr James Matthew',
#  'McKane, Mr Peter D',
#  'Mellenger, Mrs Elizabeth Anne',
#  'Mellenger, Miss Madeleine Violet',
#  'Mellor, Mr William John',
#  'Meyer, Mr August',
#  'Milling, Mr Jacob Christian',
#  'Mitchell, Mr Henry Michael',
#  'Moraweck, Dr Ernest',
#  'Morley, Mr William',
#  'Mudd, Mr Thomas C',
#  'Myles, Mr Thomas Francis',
#  'Nasser (Nasrallah), Mr Nicholas',
#  'Nasser (Nasrallah), Mrs Nicholas',
#  'Navratil, Master Edmond Roger',
#  'Navratil, Mr Michel',
#  'Navratil, Master Michel M',
#  'Nesson, Mr Israel',
#  'Nicholls, Mr Joseph Charles',
#  'Norman, Mr Robert Douglas',
#  'Nourney, Mr Alfred (aka Baron von Drachstedt)',
#  'Nye, Mrs Elizabeth Ramell',
#  'Otter, Mr Richard',
#  'Oxenham, Mr Percy Thomas',
#  'Padro y Manent, Mr Julian',
#  'Pain, Dr Alfred',
#  'Pallas y Castello, Mr Emilio',
#  'Parker, Mr Clifford R',
#  'Parkes, Mr Francis (Frank)',
#  'Parrish, Mrs Lutie Davis',
#  'Pengelly, Mr Frederick',
#  'Peruschitz, Rev Joseph M',
#  'Phillips, Miss Alice',
#  'Phillips, Mr Robert',
#  'Pinsky, Miss Rosa',
#  'Ponesell, Mr Martin',
#  'Portaluppi, Mr Emilio',
#  'Pulbaum, Mr Frank',
#  'Quick, Mrs Frederick C (Jane Richards)',
#  'Quick, Miss Phyllis May',
#  'Quick, Miss Winifred Vera',
#  'Reeves, Mr David',
#  'Renouf, Mr Peter Henry',
#  'Renouf, Mrs Peter Henry (Lillian Jefferys)',
#  'Reynaldo, Mrs Encarnacion',
#  'Richard, Mr Emil',
#  'Richards, Master George Sidney',
#  'Richards, Mrs Sidney (Emily Hocking)',
#  'Richards, Master William Rowe',
#  'Ridsdale, Miss Lucy',
#  'Rogers, Mr Harry',
#  'Rugg, Miss Emily',
#  'Sedgwick, Mr Charles Frederick Waddington',
#  'Sharp, Mr Percival',
#  'Shelley, Mrs William (Imanita)',
#  'Silven, Miss Lyyli',
#  'Sincock, Miss Maude',
#  'Siukonnen, Miss Anna',
#  'Sjostedt, Mr Ernst Adolf',
#  'Slayter, Miss Hilda Mary',
#  'Slemen, Mr Richard James',
#  'Smith (Schmidt), Mr Augustus',
#  'Smith, Miss Marion',
#  'Sobey, Mr Hayden',
#  'Stanton, Mr Samuel Ward',
#  'Stokes, Mr Philip Joseph',
#  'Sweet, Mr George',
#  'Toomey, Miss Ellen',
#  'Troupiansky, Mr Moses Aaron',
#  'Trout, Mrs William H (Jessie L)',
#  'Troutt, Miss Edwina Celia',
#  'Turpin, Mr William John',
#  'Turpin, Mrs William John (Dorothy Anne Wonnacott)',
#  'Veale, Mr James',
#  'Waelens, Mr Achille',
#  'Walcroft, Miss Nellie',
#  'Ware, Mr John James',
#  'Ware, Mrs John James (Florence Louise Long)',
#  'Ware, Mr William J',
#  'Watson, Mr Ennis Hastings',
#  'Watt, Miss Bertha',
#  'Watt, Mrs James (Bessie Inglis Milne)',
#  'Webber, Miss Susan',
#  'Weisz, Mr Leopold',
#  'Weisz, Mrs Leopold (Mathilde)',
#  'Wells, Mrs Arthur H (Addie Trevaskis)',
#  'Wells, Miss Joan',
#  'Wells, Master Ralph Lester',
#  'West, Miss Barbara J',
#  'West, Miss Constance Mirium',
#  'West, Mr Edwy Arthur',
#  'West, Mrs Edwy Arthur (Ada Mary)',
#  'Wheadon, Mr Edward',
#  'Wheeler, Mr Edwin',
#  'Wheeler, Mr Frederick',
#  'Wilhelms, Mr Charles',
#  'Wilkinson, Mrs Elizabeth Anne',
#  'Williams, Mr Charles Eugene',
#  'Wright, Miss Marion',
#  'Yrois, Miss Henriette',
#  'Aldworth, Mr Charles Augustus',
#  'Brown, Miss Mildred',
#  'Pernot, Mr Rene',
#  'Swane, Mr George',
#  'Abbing, Mr Anthony',
#  'Abbott, Master Eugene Joseph',
#  'Abbott, Mr Rossmore Edward',
#  'Abbott, Mrs Stanton (Rosa)',
#  'Abelseth, Miss Anna Karen',
#  'Abelseth, Mr Olaus',
#  'Abraham, Mrs Joseph (Sophie Easu)',
#  'Abrahamsson, Mr August',
#  'Adahl, Mr Mauritz Nils Martin',
#  'Adams, Mr John',
#  'Ahlin, Mrs Johanna Persdotter',
#  'Ahmed, Mr Ali',
#  'Aijo-Nirva, Mr Isak',
#  'Aks, Mrs Sam (Leah Rosen)',
#  'Aks, Master Philip',
#  'Alexander, Mr William',
#  'Alhomaki, Mr Ilmari Rudolf',
#  'Ali, Mr William',
#  'Allen, Mr William Henry',
#  'Allum, Mr Owen George',
#  'Andersen, Mr Albert Karvin',
#  'Andersen, Mr Thor Olsvigen',
#  'Andersson, Mr Anders Johan',
#  'Andersson, Mrs Anders Johan (Alfrida K Brogren)',
#  'Andersson, Miss Ebba Iris',
#  'Andersson, Miss Ellis Anna Maria',
#  'Andersson, Miss Erna',
#  'Andersson, Miss Ida Augusta Margareta',
#  'Andersson, Miss Ingeborg Constancia',
#  'Andersson, Mr Johan Samuel',
#  'Andersson, Miss Sigrid Elizabeth',
#  'Andersson, Master Sigvard Harald Elias',
#  'Andreasson, Mr Paul Edvin',
#  'Angheloff, Mr Minko',
#  'Arnold, Mr Josef',
#  'Arnold, Mrs Josef (Josephine Frank)',
#  'Aronsson, Mr Ernst Axel Algot',
#  'Asim, Mr Adola',
#  'Asplund, Mr Carl Oscar Vilhelm Gustafsson',
#  'Asplund, Mrs Carl Oscar (Selma Augusta Johansson)',
#  'Asplund, Master Carl Edgar',
#  'Asplund, Master Clarence Gustaf Hugo',
#  'Aspland, Master Edvin Rojj Felix',
#  'Asplund, Master Filip Oscar',
#  'Asplund, Mr John Charles',
#  'Asplund, Miss Lillian Gertrud',
#  'Assaf, Mr Gerios',
#  'Assaf, Mrs Mariana',
#  'Assam, Mr Ali',
#  'Attalah, Miss Malaka',
#  'Attala (Kalil), Mr Solomon',
#  'Augustsson, Mr Albert',
#  'Baccos, Mr Rafoul',
#  'Backstrom, Mr Karl Alfred',
#  'Backstrom, Mrs Karl Alfred (Maria Mathilda Gustafsson)',
#  'Baclini, Miss Eugenie',
#  'Baclini, Miss Helene',
#  'Baclini, Miss Maria',
#  'Baclini, Mrs Solomon (Latifa)',
#  'Badman, Miss Emily Louisa',
#  'Badt, Mr Mohamed',
#  'Balkic, Mr Cerin',
#  'Banoura, Miss Ayout',
#  'Barbara, Mrs Catherine',
#  'Barbara, Miss Saude',
#  'Barry, Miss Julia',
#  'Barton, Mr David',
#  'Beavan, Mr William Thomas',
#  'Bengtsson, Mr John Viktor',
#  'Berglund, Mr Karl Ivar Sven',
#  'Betros, Mr Tannous',
#  'Bing, Mr Lee',
#  'Birkeland, Mr Hans',
#  'Bjorklund, Ernst Herbert',
#  'Bostandyeff, Mr Guentcho',
#  'Boulos, Master Akar',
#  'Boulos, Mr Hanna',
#  'Boulos, Mrs Joseph (Sultana)',
#  'Boulos, Miss Laura',
#  'Bourke, Mr John',
#  'Bourke, Mrs John (Catherine)',
#  'Bourke, Miss Mary',
#  'Bowen, Mr David',
#  'Bradley, Miss Bridget Delia',
#  'Braf, Miss Elin Ester Maria',
#  'Brahim, Mr Youssef',
#  'Braund, Mr Lewis Richard',
#  'Braund, Mr Owen Harris',
#  'Brobek, Mr Karl Rudolf',
#  'Brocklebank, Mr William Alfred',
#  'Buckley, Mr Daniel',
#  'Buckley, Miss Katherine',
#  'Burke, Mr Jeremiah',
#  'Burns, Miss Mary Delia',
#  'Cacic, Mr Grego',
#  'Cacic, Mr Luka',
#  'Cacic, Mr Manda',
#  'Cacic, Mr Maria',
#  'Calic, Mr Peter',
#  'Canavan, Miss Mary',
#  'Canavan, Mr Patrick',
#  'Cann, Mr Ernest',
#  'Caram (Kareem), Mr Joseph',
#  'Caram (Kareem), Mrs Joseph (Maria Elias)',
#  'Carlsson, Mr Carl Robert',
#  'Carlsson, Mr Frans Olof',
#  'Carlsson, Mr Julius',
#  'Carlsson, Mr August Sigfrid',
#  'Carr, Miss Helen',
#  'Carr, Miss Jeannie',
#  'Carver, Mr Alfred John',
#  'Cassem, Mr Nassef Belmenly',
#  'Celotti, Mr Francesco',
#  'Chartens, Mr David',
#  'Chebab, Mr Emir Farres',
#  'Chip, Mr Chang',
#  'Christmann, Mr Emil',
#  'Chronopoulos, Mr Apostolos',
#  'Chronopoulos, Mr Demetrios',
#  'Coelho, Mr Domingos Fernandes',
#  'Cohen, Mr Gurshon (Gus)',
#  'Colbert, Mr Patrick',
#  'Coleff, Mr Fotio',
#  'Coleff, Mr Peyo',
#  'Conlin, Mr Thomas Henry',
#  'Connaghton, Mr Michael',
#  'Connolly, Miss Kate',
#  'Connolly, Miss Kate',
#  'Connors, Mr Patrick',
#  'Cook, Mr Jacob',
#  'Cor, Mr Bartol',
#  'Cor, Mr Ivan',
#  'Cor, Mr Ludovik',
#  'Corn, Mr Harry',
#  'Coutts, Mrs William (Minnie)',
#  'Coutts, Master Neville',
#  'Coutts, Master William Leslie',
#  'Coxon, Mr Daniel',
#  'Crease, Mr Ernest James',
#  'Cribb, Mr John Hatfield',
#  'Cribb, Miss Laura Alice',
#  'Daher, Mr Tannous',
#  'Dahl, Mr Charles Edward',
#  'Dahlberg, Miss Gerda Ulrika',
#  'Dakic, Mr Branko',
#  'Daly, Mr Eugene',
#  'Daly, Miss Marcella',
#  'Danbom, Mr Ernst Gilbert',
#  'Danbom, Mrs Ernst Gilbert (Anna Sigrid Maria Brogren)',
#  'Danbom, Master Gilbert Sigvard Emanuel',
#  'Danoff, Mr Yoto',
#  'Dantchoff, Mr Khristo',
#  'Davies, Mr Alfred',
#  'Davies, Mr Evan',
#  'Davies, Mr John',
#  'Davies, Mr Joseph',
#  'Davison, Mr Thomas Henry',
#  'Davison, Mrs Thomas Henry (Mary Finck)',
#  'Dean, Mr Bertram',
#  'Dean, Mrs Bertram (Eva)',
#  'Dean, Master Bertram Vere',
#  'Dean, Miss Elizabeth Gladys (Millvena)',
#  'Delalic, Mr Regyo',
#  'De Messemaeker, Mr William Joseph',
#  'De Messemaeker, Mrs William Joseph (Anna)',
#  'De Mulder, Mr Theo',
#  'Denkoff, Mr Mito',
#  'Dennis, Mr Samuel',
#  'Dennis, Mr William',
#  'Devaney, Miss Margaret',
#  'Dewan, Mr Frank',
#  'Dibo, Mr Elias',
#  'Dimic, Mr Jovan',
#  'Dintcheff, Mr Valtcho',
#  'Dooley, Mr Patrick',
#  'Dorkings, Mr Edward Arthur',
#  'Dowdell, Miss Elizabeth',
#  'Doyle, Miss Elizabeth',
#  'Drapkin, Miss Jennie',
#  'Drazonovic, Mr Josef',
#  'Driscoll, Miss Bridget',
#  'Duquemin, Mr Joseph',
#  'Dyker, Mr Adolf Fredrik',
#  'Dyker, Mrs Adolf Fredrik (Anna Elizabeth Judith Andersson)',
#  'Econovic, Mr Joso',
#  'Edvardsson, Mr Gustaf Hjalmar',
#  'Eklund, Mr Hans Linus',
#  'Ekstrom, Mr Johan',
#  'Elias, Mr Elias',
#  'Elias, Mr John',
#  'Elias, Mr Joseph',
#  'Elsbury, Mr James',
#  'Emanuel, Miss Virginia Ethel',
#  'Emmeth, Mr Thomas',
#  'Everett, Thomas James',
#  'Farrell, Mr James',
#  'Finoli, Mr Luigi',
#  'Fischer, Mr Eberhard Telander',
#  'Flynn, Mr James',
#  'Flynn, Mr John',
#  'Foley, Mr Joseph',
#  'Foley, Mr William',
#  'Foo, Mr Choong',
#  'Ford, Mr Arthur',
#  'Ford, Miss Doolina Margaret',
#  'Ford, Mr Edward Watson',
#  'Ford, Miss Maggie',
#  'Ford, Mrs Edward (Margaret Ann)',
#  'Ford, Mr Neil Watson',
#  'Fox, Mr Patrick',
#  'Franklin, Mr Charles',
#  'Gallagher, Mr Martin',
#  'Garfirth, Mr John',
#  'Georges, Mrs Shahini Weappi',
#  'Gilinski, Mr Leslie',
#  'Gilnagh, Miss Katie',
#  'Glynn, Miss Mary Agatha',
#  'Goldsmith, Mr Frank John',
#  'Goldsmith, Mrs Frank John (Emily A Brown)',
#  'Goldsmith, Master Frank John William',
#  'Goldsmith, Mr Nathan',
#  'Goncalves, Mr Manuel Estanslas',
#  'Goodwin, Mr Frederick',
#  'Goodwin, Mrs Frederick (Augusta)',
#  'Goodwin, Mr Charles E',
#  'Goodwin, Miss Lillian A',
#  'Goodwin, Master Harold V',
#  'Goodwin, Miss Jessie A',
#  'Goodwin, Master Sidney L',
#  'Goodwin, Master William F',
#  'Green, Mr George',
#  'Gronnestad, Mr Daniel Danielsen',
#  'Guest, Mr Robert',
#  'Gustafsson, Mr Alfred Ossian',
#  'Gustafsson, Mr Anders Vilhelm',
#  'Gustafsson, Mr Johan Birger',
#  'Gustafsson, Mr Karl Gideon',
#  'Haas, Miss Aloisia',
#  'Hagardon, Miss Kate',
#  'Hagland, Mr Ingvald Olsen',
#  'Hagland, Mr Konrad Mathias Reiersen',
#  'Hakkarainen, Mr Pekko Pietari',
#  'Hakkarainen, Mrs Pekko Pietari',
#  'Hampe, Mr Leon',
#  'Hansen, Mr Claus Peter',
#  'Hansen, Mrs Claus Peter',
#  'Hansen, Mr Henrik Juul',
#  'Hansen, Mr Henry Damsgaard',
#  'Harknett, Miss Alice',
#  'Harmer, Mr Abraham',
#  'Hart, Mr Henry',
#  'Hassan, Mr M Houssein',
#  'Healy, Miss Nora',
#  'Hedman, Mr Oscar',
#  'Hee, Mr Ling',
#  'Hegarty, Miss Nora',
#  'Heikkinen, Miss Laina',
#  'Heininen, Miss Wendla Maria',
#  'Hellstrom, Hilda Maria',
#  'Hemming, Miss Nora',
#  'Hendekovic, Mr Ignaz',
#  'Henery, Delia',
#  'Henriksson, Jenny Lovisa',
#  'Hirvonen, Mrs Alexander',
#  'Hirvonen, Miss Hildur E',
#  'Holm, Mr John Frederik Alexander',
#  'Holthen, Mr Johan Martin',
#  'Honkanen, Miss Eluna',
#  'Horgan, Mr John',
#  'Howard, Miss May',
#  'Humblin, Mr Adolf Mathias Nicolai Olsen',
#  'Hyman, Mr Abraham',
#  'Ilieff, Mr Ylio',
#  'Ilmakangas, Miss Ida Livija',
#  'Ilmakangas, Miss Pieta Sofia',
#  'Ivanoff, Mr Konio',
#  'Jansen, Mr Carl Olof',
#  'Jardin, Mr Jose Netto',
#  'Jensen, Miss Carla Christine',
#  'Jensen, Mr Hans Peder',
#  'Jensen, Mr Niels Peder',
#  'Jensen, Mr Svend Lauritz',
#  'Jermyn, Miss Annie',
#  'Johannesen-Bratthammer, Mr Bernt',
#  'Johanson, Mr Jakob Alfred',
#  'Johansson, Mr Erik',
#  'Johansson, Mr Gustaff Joel',
#  'Johansson, Mr Karl Johan',
#  'Johansson, Mr Nils',
#  'Johansson, Oscar L',
#  'Johnson, Mr Alfred',
#  'Johnson, Miss Eleanor Ileen',
#  'Johnson, Mr Malkolm Joackim',
#  'Johnson, Master Harold Theodor',
#  'Johnson, Mrs Oscar W',
#  'Johnson, Mr William Cahoone Jr',
#  'Johnston, Mr Andrew G',
#  'Johnston, Mrs Andrew G',
#  'Johnston, Miss Catherine H',
#  'Johnston, Master William A',
#  'Jonkoff, Mr Lazor',
#  'Jonsson, Mr Carl',
#  'Jonsson, Nils Hilding',
#  'Jussila, Miss Aina Maria',
#  'Jussila, Mr Erik',
#  'Jussila, Miss Katriina',
#  'Kallio, Mr Nikolai Erland',
#  'Kalvig, Mr Johannes K Halverson',
#  'Karajic, Mr Milan',
#  'Karlsson, Mr Einar Gervasius',
#  'Karlsson, Mr Julius Konrad Eugen',
#  'Karlsson, Mr Nils August',
#  'Karun, Miss Anna Mary',
#  'Karun, Mr Franz',
#  'Kassem, Mr Fared',
#  'Keane, Mr Andrew',
#  'Keefe, Mr Arthur',
#  'Kekic, Mr Tido',
#  'Kelly, Miss Anna Kate',
#  'Kelly, Mr James',
#  'Kelly, Mr James',
#  'Kelly, Miss Mary',
#  'Kennedy, Mr John',
#  'Khalil, Mr Betros',
#  'Khalil, Mrs Betros',
#  'Khalil, Mr Saad',
#  'Kiernan, Mr John',
#  'Kiernan, Mr Philip',
#  'Kilgannon, Mr Thomas',
#  'Kink, Mr Anton',
#  'Kink, Mrs Anton (Louise Heilmann)',
#  'Kink, Miss Louise Gretchen',
#  'Kink, Miss Maria',
#  'Kink, Mr Vincenz',
#  'Klasen, Miss Gertrud Emilia',
#  'Klasen, Mrs Hulda Kristina',
#  'Klasen, Mr Klas Albin',
#  'Kraeff, Mr Theodor',
#  'Krekorian, Mr Neshan',
#  'Lahowd, Mr Sarkis',
#  'Laitinen, Miss Kritina Sofia',
#  'Laleff, Mr Kristo',
#  'Lam, Mr Ali',
#  'Lam, Mr Len',
#  'Landegren, Miss Aurora Adelia',
#  'Lane, Mr Patrick',
#  'Lang, Mr Fang',
#  'Larsson, Mr August Viktor',
#  'Larsson, Mr Bengt Edvin',
#  'Larsson-Rondberg, Mr Edvard',
#  'Leeni, Mr Fahim',
#  'Lefebre, Mrs Frank',
#  'Lefebre, Master Henry',
#  'Lefebre, Miss Ida',
#  'Lefebre, Miss Jeannie',
#  'Lefebre, Miss Mathilde',
#  'Leinonen, Mr Antti Gustaf',
#  'Lemberopolous, Mr Peter L',
#  'Lemom, Mr Denis',
#  'Lemon, Miss Mary',
#  'Leonard, Mr Lionel',
#  'Lester, Mr James',
#  'Lindahl, Miss Agda V',
#  'Lindblom, Miss Augusta Charlotta',
#  'Lindell, Mr Edvard Bengtsson',
#  'Lindell, Mrs Edvard Bengtsson',
#  'Lindqvist, Eino William',
#  'Linehan, Mr Michael',
#  'Ling, Mr Lee',
#  'Lithman, Mr Simon',
#  'Lobb, Mr William Arthur',
#  'Lobb, Mrs William Arthur',
#  'Lockyer, Mr Edward',
#  'Lovell, Mr John',
#  'Lulich, Mr Nicola',
#  'Lundahl, Mr Johan',
#  'Lundin, Miss Olga Elida',
#  'Lundstrom, Mr Thure Edvin',
#  'Lyntakoff, Mr Stanko',
#  'MacKay, Mr George William',
#  'Madigan, Miss Margaret',
#  'Madsen, Mr Frithiof',
#  'Maenpaa, Mr Matti Alexanteri',
#  'Mahon, Miss Delia',
#  'Maisner, Mr Simon',
#  'Makinen, Mr Kalle Edvard',
#  'Mamee, Mr Hanna',
#  'Mangan, Miss Mary',
#  'Mannion, Miss Margareth',
#  'Mansour, Mr Hanna',
#  'Mardirosian, Mr Sarkis',
#  'Marinko, Mr Dmitri',
#  'Markim, Mr Johann',
#  'Markoff, Mr Marin',
#  'Masselmany, Mrs Fatima',
#  'Matinoff, Mr Nicola',
#  'McCarthy, Miss Katie',
#  'McCormack, Mr Thomas J',
#  ...]

# %% [markdown]
# ## Query Passenger Details

# %%
session = Session(engine)

# %%
# Query all passengers
results = session.query(Passenger.name, Passenger.age, Passenger.sex).all()

# %%
session.close()

# %%
# Create a dictionary from the row data and append to a list of all_passengers
all_passengers = []
for name, age, sex in results:
    passenger_dict = {}
    passenger_dict["name"] = name
    passenger_dict["age"] = age
    passenger_dict["sex"] = sex
    all_passengers.append(passenger_dict)

all_passengers
# Out:
# [{'name': 'Allen, Miss Elisabeth Walton', 'age': 29.0, 'sex': 'female'},
#  {'name': 'Allison, Miss Helen Loraine', 'age': 2.0, 'sex': 'female'},
#  {'name': 'Allison, Mr Hudson Joshua Creighton', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Allison, Mrs Hudson JC (Bessie Waldo Daniels)',
#   'age': 25.0,
#   'sex': 'female'},
#  {'name': 'Allison, Master Hudson Trevor', 'age': 0.92, 'sex': 'male'},
#  {'name': 'Anderson, Mr Harry', 'age': 47.0, 'sex': 'male'},
#  {'name': 'Andrews, Miss Kornelia Theodosia', 'age': 63.0, 'sex': 'female'},
#  {'name': 'Andrews, Mr Thomas, jr', 'age': 39.0, 'sex': 'male'},
#  {'name': 'Appleton, Mrs Edward Dale (Charlotte Lamson)',
#   'age': 58.0,
#   'sex': 'female'},
#  {'name': 'Artagaveytia, Mr Ramon', 'age': 71.0, 'sex': 'male'},
#  {'name': 'Astor, Colonel John Jacob', 'age': 47.0, 'sex': 'male'},
#  {'name': 'Astor, Mrs John Jacob (Madeleine Talmadge Force)',
#   'age': 19.0,
#   'sex': 'female'},
#  {'name': 'Aubert, Mrs Leontine Pauline', 'age': None, 'sex': 'female'},
#  {'name': 'Barkworth, Mr Algernon H', 'age': None, 'sex': 'male'},
#  {'name': 'Baumann, Mr John D', 'age': None, 'sex': 'male'},
#  {'name': 'Baxter, Mrs James (Helene DeLaudeniere Chaput)',
#   'age': 50.0,
#   'sex': 'female'},
#  {'name': 'Baxter, Mr Quigg Edmond', 'age': 24.0, 'sex': 'male'},
#  {'name': 'Beattie, Mr Thomson', 'age': 36.0, 'sex': 'male'},
#  {'name': 'Beckwith, Mr Richard Leonard', 'age': 37.0, 'sex': 'male'},
#  {'name': 'Beckwith, Mrs Richard Leonard (Sallie Monypeny)',
#   'age': 47.0,
#   'sex': 'female'},
#  {'name': 'Behr, Mr Karl Howell', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Birnbaum, Mr Jakob', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Bishop, Mr Dickinson H', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Bishop, Mrs Dickinson H (Helen Walton)',
#   'age': 19.0,
#   'sex': 'female'},
#  {'name': 'Bjornstrm-Steffansson, Mr Mauritz Hakan',
#   'age': 28.0,
#   'sex': 'male'},
#  {'name': 'Blackwell, Mr Stephen Weart', 'age': 45.0, 'sex': 'male'},
#  {'name': 'Blank, Mr Henry', 'age': 39.0, 'sex': 'male'},
#  {'name': 'Bonnell, Miss Caroline', 'age': 30.0, 'sex': 'female'},
#  {'name': 'Bonnell, Miss Elizabeth', 'age': 58.0, 'sex': 'female'},
#  {'name': 'Borebank, Mr John James', 'age': None, 'sex': 'male'},
#  {'name': 'Bowen, Miss Grace Scott', 'age': 45.0, 'sex': 'female'},
#  {'name': 'Bowerman, Miss Elsie Edith', 'age': 22.0, 'sex': 'female'},
#  {'name': 'Bradley, Mr George', 'age': None, 'sex': 'male'},
#  {'name': 'Brady, Mr John Bertram', 'age': 41.0, 'sex': 'male'},
#  {'name': 'Brandeis, Mr Emil', 'age': 48.0, 'sex': 'male'},
#  {'name': 'Brewe, Dr Arthur Jackson', 'age': None, 'sex': 'male'},
#  {'name': 'Brown, Mrs James Joseph (Margaret Molly" Tobin)"',
#   'age': 44.0,
#   'sex': 'female'},
#  {'name': 'Brown, Mrs John Murray (Caroline Lane Lamson)',
#   'age': 59.0,
#   'sex': 'female'},
#  {'name': 'Bucknell, Mrs William Robert (Emma Eliza Ward)',
#   'age': 60.0,
#   'sex': 'female'},
#  {'name': 'Butt, Major Archibald Willingham', 'age': 45.0, 'sex': 'male'},
#  {'name': 'Calderhead, Mr Edward P', 'age': None, 'sex': 'male'},
#  {'name': 'Candee, Mrs Edward (Helen Churchill Hungerford)',
#   'age': 53.0,
#   'sex': 'female'},
#  {'name': 'Cardeza, Mrs James Warburton Martinez (Charlotte Wardle Drake)',
#   'age': 58.0,
#   'sex': 'female'},
#  {'name': 'Cardeza, Mr Thomas Drake Martinez', 'age': 36.0, 'sex': 'male'},
#  {'name': 'Carlsson, Mr Frans Olof', 'age': 33.0, 'sex': 'male'},
#  {'name': 'Carrau, Mr Francisco M', 'age': None, 'sex': 'male'},
#  {'name': 'Carrau, Mr Jose Pedro', 'age': None, 'sex': 'male'},
#  {'name': 'Carter, Mr William Ernest', 'age': 36.0, 'sex': 'male'},
#  {'name': 'Carter, Mrs William Ernest (Lucile Polk)',
#   'age': 36.0,
#   'sex': 'female'},
#  {'name': 'Carter, Miss Lucile Polk', 'age': 14.0, 'sex': 'female'},
#  {'name': 'Carter, Master William T II', 'age': 11.0, 'sex': 'male'},
#  {'name': 'Case, Mr Howard Brown', 'age': 49.0, 'sex': 'male'},
#  {'name': 'Cassebeer, Mrs Henry Arthur jr (Genevieve Fosdick)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Cavendish, Mr Tyrell William', 'age': 36.0, 'sex': 'male'},
#  {'name': 'Cavendish, Mrs Tyrell William Julia Florence Siegel',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Chaffee, Mr Herbert Fuller', 'age': 46.0, 'sex': 'male'},
#  {'name': 'Chaffee, Mrs Herbert Fuller (Carrie Constance Toogood)',
#   'age': 47.0,
#   'sex': 'female'},
#  {'name': 'Chambers, Mr Norman Campbell', 'age': 27.0, 'sex': 'male'},
#  {'name': 'Chambers, Mrs Norman Campbell (Bertha Griggs)',
#   'age': 31.0,
#   'sex': 'female'},
#  {'name': 'Cherry, Miss Gladys', 'age': None, 'sex': 'female'},
#  {'name': 'Chevre, Mr Paul', 'age': None, 'sex': 'male'},
#  {'name': 'Chibnall (Bowerman), Mrs Edith Martha',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Chisholm, Mr Roderick Robert', 'age': None, 'sex': 'male'},
#  {'name': 'Clark, Mr Walter Miller', 'age': 27.0, 'sex': 'male'},
#  {'name': 'Clark, Mrs Walter Miller (Virginia McDowell)',
#   'age': 26.0,
#   'sex': 'female'},
#  {'name': 'Clifford, Mr George Quincy', 'age': None, 'sex': 'male'},
#  {'name': 'Colley, Mr Edward Pomeroy', 'age': None, 'sex': 'male'},
#  {'name': 'Compton, Mrs Alexander Taylor (Mary Eliza Ingersoll)',
#   'age': 64.0,
#   'sex': 'female'},
#  {'name': 'Compton, Mr Alexander Taylor, Jr', 'age': 37.0, 'sex': 'male'},
#  {'name': 'Compton, Miss Sara Rebecca', 'age': 39.0, 'sex': 'female'},
#  {'name': 'Cornell, Mrs Robert Clifford (Malvina Helen Lamson)',
#   'age': 55.0,
#   'sex': 'female'},
#  {'name': 'Crafton, Mr John Bertram', 'age': None, 'sex': 'male'},
#  {'name': 'Crosby, Captain Edward Gifford', 'age': 70.0, 'sex': 'male'},
#  {'name': 'Crosby, Mrs Edward Gifford (Catherine Elizabeth Halstead)',
#   'age': 69.0,
#   'sex': 'female'},
#  {'name': 'Crosby, Miss Harriet R', 'age': 36.0, 'sex': 'female'},
#  {'name': 'Cumings, Mr John Bradley', 'age': 39.0, 'sex': 'male'},
#  {'name': 'Cumings, Mrs John Bradley (Florence Briggs Thayer)',
#   'age': 38.0,
#   'sex': 'female'},
#  {'name': 'Daly, Mr Peter Denis ', 'age': None, 'sex': 'male'},
#  {'name': 'Daniel, Mr Robert Williams', 'age': 27.0, 'sex': 'male'},
#  {'name': 'Davidson, Mr Thornton', 'age': 31.0, 'sex': 'male'},
#  {'name': 'Davidson, Mrs Thornton (Orian Hays)', 'age': 27.0, 'sex': 'female'},
#  {'name': 'de Villiers, Madame Berthe', 'age': None, 'sex': 'female'},
#  {'name': 'Dick, Mr Albert Adrian', 'age': 31.0, 'sex': 'male'},
#  {'name': 'Dick, Mrs Albert Adrian Vera Gillespie',
#   'age': 17.0,
#   'sex': 'female'},
#  {'name': 'Dodge, Dr Washington', 'age': None, 'sex': 'male'},
#  {'name': 'Dodge, Mrs Washington (Ruth Vidaver)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Dodge, Master Washington', 'age': 4.0, 'sex': 'male'},
#  {'name': 'Douglas, Mrs Frederick Charles (Suzette Baxter)',
#   'age': 27.0,
#   'sex': 'female'},
#  {'name': 'Douglas, Mr Walter Donald', 'age': 50.0, 'sex': 'male'},
#  {'name': 'Douglas, Mrs Walter Donald (Mahala Dutton)',
#   'age': 48.0,
#   'sex': 'female'},
#  {'name': 'Duff Gordon, Sir Cosmo Edmund', 'age': 49.0, 'sex': 'male'},
#  {'name': 'Duff Gordon, Lady (Lucille Wallace Sutherland)',
#   'age': 48.0,
#   'sex': 'female'},
#  {'name': 'Dulles, Mr William Crothers', 'age': 39.0, 'sex': 'male'},
#  {'name': 'Earnshaw, Mrs Boulton (Olive Potter)',
#   'age': 23.0,
#   'sex': 'female'},
#  {'name': 'Eustis, Miss Elizabeth Mussey', 'age': 53.0, 'sex': 'female'},
#  {'name': 'Evans, Miss Edith Corse', 'age': 36.0, 'sex': 'female'},
#  {'name': 'Flegenheim, Mrs Alfred (Antoinette)', 'age': None, 'sex': 'female'},
#  {'name': 'Flynn, Mr John Irving', 'age': None, 'sex': 'male'},
#  {'name': 'Foreman, Mr Benjamin Laventall', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Fortune, Miss Alice Elizabeth', 'age': 24.0, 'sex': 'female'},
#  {'name': 'Fortune, Mr Charles Alexander', 'age': 19.0, 'sex': 'male'},
#  {'name': 'Fortune, Miss Ethel Flora', 'age': 28.0, 'sex': 'female'},
#  {'name': 'Fortune, Miss Mabel', 'age': 23.0, 'sex': 'female'},
#  {'name': 'Fortune, Mr Mark', 'age': 64.0, 'sex': 'male'},
#  {'name': 'Fortune, Mrs Mark (Mary McDougald)', 'age': 60.0, 'sex': 'female'},
#  {'name': 'Franklin, Mr Thomas Parham', 'age': None, 'sex': 'male'},
#  {'name': 'Frauenthal, Dr Henry William', 'age': 49.0, 'sex': 'male'},
#  {'name': 'Frauenthal, Mrs Henry William (Clara Heinsheimer)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Frauenthal, Mr Isaac Gerald', 'age': 44.0, 'sex': 'male'},
#  {'name': 'Frolicher, Miss Marguerite', 'age': 22.0, 'sex': 'female'},
#  {'name': 'Frolicher-Stehli, Mr Maxmillian', 'age': 60.0, 'sex': 'male'},
#  {'name': 'Frolicher-Stehli, Mrs Maxmillian (Margaretha Emerentia Stehli)',
#   'age': 48.0,
#   'sex': 'female'},
#  {'name': 'Futrelle, Mr Jacques', 'age': 37.0, 'sex': 'male'},
#  {'name': 'Futrelle, Mrs Jacques (May Peel)', 'age': 35.0, 'sex': 'female'},
#  {'name': 'Gee, Mr Arthur H', 'age': 47.0, 'sex': 'male'},
#  {'name': 'Gibson, Miss Dorothy', 'age': 22.0, 'sex': 'female'},
#  {'name': 'Gibson, Mrs Leonard (Pauline C Boeson)',
#   'age': 45.0,
#   'sex': 'female'},
#  {'name': 'Goldenberg, Mr Samuel L', 'age': 49.0, 'sex': 'male'},
#  {'name': 'Goldenberg, Mrs Samuel L (Edwiga Grabowsko)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Goldschmidt, Mr George B', 'age': 71.0, 'sex': 'male'},
#  {'name': 'Gracie, Colonel Archibald IV', 'age': 54.0, 'sex': 'male'},
#  {'name': 'Graham, Mr George Edward', 'age': 38.0, 'sex': 'male'},
#  {'name': 'Graham, Miss Margaret Edith', 'age': 19.0, 'sex': 'female'},
#  {'name': 'Graham, Mrs William Thompson (Edith Junkins)',
#   'age': 58.0,
#   'sex': 'female'},
#  {'name': 'Greenfield, Mrs Leo David (Blanche Strouse)',
#   'age': 45.0,
#   'sex': 'female'},
#  {'name': 'Greenfield, Mr William Bertram', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Guggenheim, Mr Benjamin', 'age': 46.0, 'sex': 'male'},
#  {'name': 'Harder, Mr George Achilles', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Harder, Mrs George Achilles (Dorothy Annan)',
#   'age': 21.0,
#   'sex': 'female'},
#  {'name': 'Harper, Mr Henry Sleeper', 'age': 48.0, 'sex': 'male'},
#  {'name': 'Harper, Mrs Henry Sleeper (Myna Haxtun)',
#   'age': 49.0,
#   'sex': 'female'},
#  {'name': 'Harris, Mr Henry Birkhardt', 'age': 45.0, 'sex': 'male'},
#  {'name': 'Harris, Mrs Henry Birkhardt (Irene Wallach)',
#   'age': 36.0,
#   'sex': 'female'},
#  {'name': 'Hawksford, Mr Walter James', 'age': None, 'sex': 'male'},
#  {'name': 'Hays, Mr Charles Melville', 'age': 55.0, 'sex': 'male'},
#  {'name': 'Hays, Mrs Charles Melville (Clara Jennings Gregg)',
#   'age': 52.0,
#   'sex': 'female'},
#  {'name': 'Hays, Miss Margaret Bechstein', 'age': 24.0, 'sex': 'female'},
#  {'name': 'Head, Mr Christopher', 'age': None, 'sex': 'male'},
#  {'name': 'Hilliard, Mr Herbert Henry', 'age': None, 'sex': 'male'},
#  {'name': 'Hipkins, Mr William Edward', 'age': None, 'sex': 'male'},
#  {'name': 'Hippach, Miss Jean Gertrude', 'age': 16.0, 'sex': 'female'},
#  {'name': 'Hippach, Mrs Louis Albert (Ida Sophia Fischer)',
#   'age': 44.0,
#   'sex': 'female'},
#  {'name': 'Hogeboom, Mrs John C (Anna Andrews)', 'age': 51.0, 'sex': 'female'},
#  {'name': 'Holverson, Mr Alexander Oskar', 'age': 42.0, 'sex': 'male'},
#  {'name': 'Holverson, Mrs Alexander Oskar (Mary Aline Towner)',
#   'age': 35.0,
#   'sex': 'female'},
#  {'name': 'Homer, Mr Harry', 'age': 35.0, 'sex': 'male'},
#  {'name': 'Hoyt, Mr Frederick Maxfield', 'age': 38.0, 'sex': 'male'},
#  {'name': 'Hoyt, Mrs Frederick Maxfield (Jane Anne Forby)',
#   'age': 35.0,
#   'sex': 'female'},
#  {'name': 'Hoyt, Mr William F', 'age': None, 'sex': 'male'},
#  {'name': 'Isham, Miss Anne Elizabeth', 'age': 50.0, 'sex': 'female'},
#  {'name': 'Ismay, Mr Joseph Bruce', 'age': 49.0, 'sex': 'male'},
#  {'name': 'Jones, Mr Charles Cresson', 'age': 46.0, 'sex': 'male'},
#  {'name': 'Julian, Mr Henry Forbes', 'age': None, 'sex': 'male'},
#  {'name': 'Kent, Mr Edward Austin', 'age': 58.0, 'sex': 'male'},
#  {'name': 'Kenyon, Mr Frederick R', 'age': 41.0, 'sex': 'male'},
#  {'name': 'Kenyon, Mrs Frederick R (Marion)', 'age': None, 'sex': 'female'},
#  {'name': 'Kimball, Mr Edwin Nelson Jr', 'age': 42.0, 'sex': 'male'},
#  {'name': 'Kimball, Mrs Edwin Nelson Jr (Gertrude Parsons)',
#   'age': 40.0,
#   'sex': 'female'},
#  {'name': 'Klaber, Mr Herman', 'age': None, 'sex': 'male'},
#  {'name': 'Leader, Dr Alice Farnham', 'age': None, 'sex': 'female'},
#  {'name': 'Lewy, Mr Ervin G', 'age': None, 'sex': 'male'},
#  {'name': 'Lindeberg-Lind, Mr Erik Gustaf', 'age': 42.0, 'sex': 'male'},
#  {'name': 'Lindstrom, Mrs Carl Johan (Sigrid Posse)',
#   'age': 55.0,
#   'sex': 'female'},
#  {'name': 'Lines, Mrs Ernest H (Elizabeth Lindsey James)',
#   'age': 50.0,
#   'sex': 'female'},
#  {'name': 'Lines, Miss Mary Conover', 'age': 16.0, 'sex': 'female'},
#  {'name': 'Lingrey, Mr Edward', 'age': None, 'sex': 'male'},
#  {'name': 'Long, Mr Milton Clyde', 'age': 29.0, 'sex': 'male'},
#  {'name': 'Longley, Miss Gretchen Fiske', 'age': 21.0, 'sex': 'female'},
#  {'name': 'Loring, Mr Joseph Holland', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Madill, Miss Georgette Alexandra', 'age': 15.0, 'sex': 'female'},
#  {'name': 'Maguire, Mr John Edward', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Marechal, Mr Pierre', 'age': None, 'sex': 'male'},
#  {'name': 'Marvin, Mr Daniel Warner', 'age': None, 'sex': 'male'},
#  {'name': 'Marvin, Mrs Daniel Warner (Mary Graham Carmichael Farquarson)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'McCaffry, Mr Thomas Francis', 'age': 46.0, 'sex': 'male'},
#  {'name': 'McCarthy, Mr Timothy J', 'age': 54.0, 'sex': 'male'},
#  {'name': 'McGough, Mr James R', 'age': 36.0, 'sex': 'male'},
#  {'name': 'Meyer, Mr Edgar Joseph', 'age': 28.0, 'sex': 'male'},
#  {'name': 'Meyer, Mrs Edgar Joseph (Leila Saks)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Millet, Mr Francis Davis', 'age': 65.0, 'sex': 'male'},
#  {'name': 'Minahan, Miss Daisy E', 'age': 33.0, 'sex': 'female'},
#  {'name': 'Minahan, Dr William Edward', 'age': 44.0, 'sex': 'male'},
#  {'name': 'Minahan, Mrs William Edward (Lillian E Thorpe)',
#   'age': 37.0,
#   'sex': 'female'},
#  {'name': 'Mock, Mr Philip E', 'age': None, 'sex': 'male'},
#  {'name': 'Molson, Mr Harry Markland', 'age': 55.0, 'sex': 'male'},
#  {'name': 'Moore, Mr Clarence Bloomfield', 'age': 47.0, 'sex': 'male'},
#  {'name': 'Natsch, Mr Charles H', 'age': 36.0, 'sex': 'male'},
#  {'name': 'Newell, Mr Arthur Webster', 'age': 58.0, 'sex': 'male'},
#  {'name': 'Newell, Miss Madeleine', 'age': 31.0, 'sex': 'female'},
#  {'name': 'Newell, Miss Marjorie', 'age': 23.0, 'sex': 'female'},
#  {'name': 'Newsom, Miss Helen Monypeny', 'age': 19.0, 'sex': 'female'},
#  {'name': 'Nicholson, Mr Arthur Ernest', 'age': 64.0, 'sex': 'male'},
#  {'name': 'Omont, Mr A Fernand', 'age': None, 'sex': 'male'},
#  {'name': 'Ostby, Mr Engelhart Cornelius', 'age': 64.0, 'sex': 'male'},
#  {'name': 'Ostby, Miss Helen Raghnild', 'age': 22.0, 'sex': 'female'},
#  {'name': 'Ovies y Rodriguez, Mr Servando', 'age': 28.0, 'sex': 'male'},
#  {'name': 'Parr, Mr William Henry Marsh', 'age': None, 'sex': 'male'},
#  {'name': 'Partner, Mr Austin', 'age': None, 'sex': 'male'},
#  {'name': 'Payne, Mr Vivian Ponsonby', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Pears, Mr Thomas', 'age': None, 'sex': 'male'},
#  {'name': 'Pears, Mrs Thomas (Edith)', 'age': None, 'sex': 'female'},
#  {'name': 'Penasco, Mr Victor de Satode', 'age': 18.0, 'sex': 'male'},
#  {'name': 'Penasco, Mrs Victor de Satode (Josefa de Soto)',
#   'age': 17.0,
#   'sex': 'female'},
#  {'name': 'Peuchen, Major Arthur Godfrey', 'age': 52.0, 'sex': 'male'},
#  {'name': 'Porter, Mr Walter Chamberlain', 'age': 46.0, 'sex': 'male'},
#  {'name': 'Potter, Mrs Thomas, Jr (Lily Alexenia Wilson)',
#   'age': 56.0,
#   'sex': 'female'},
#  {'name': 'Reuchlin, Jonkheer John George', 'age': None, 'sex': 'male'},
#  {'name': 'Rheims, Mr George Lucien', 'age': None, 'sex': 'male'},
#  {'name': 'Robert, Mrs Edward Scott (Elisabeth Walton McMillan)',
#   'age': 43.0,
#   'sex': 'female'},
#  {'name': 'Roebling, Mr Washington Augustus 2nd', 'age': 31.0, 'sex': 'male'},
#  {'name': 'Romaine, Mr Charles Hallace', 'age': None, 'sex': 'male'},
#  {'name': 'Rood, Mr Hugh R', 'age': None, 'sex': 'male'},
#  {'name': 'Rosenbaum (Russell), Miss Edith Louise',
#   'age': 33.0,
#   'sex': 'female'},
#  {'name': 'Ross, Mr John Hugo', 'age': None, 'sex': 'male'},
#  {'name': 'Rothes, the Countess of (Noel Lucy Martha Dyer-Edwardes)',
#   'age': 27.0,
#   'sex': 'female'},
#  {'name': 'Rothschild, Mr Martin', 'age': 55.0, 'sex': 'male'},
#  {'name': 'Rothschild, Mrs Martin (Elizabeth L Barrett)',
#   'age': 54.0,
#   'sex': 'female'},
#  {'name': 'Rowe, Mr Alfred G', 'age': None, 'sex': 'male'},
#  {'name': 'Ryerson, Mr Arthur Larned', 'age': 61.0, 'sex': 'male'},
#  {'name': 'Ryerson, Mrs Arthur Larned (Emily Maria Borie)',
#   'age': 48.0,
#   'sex': 'female'},
#  {'name': 'Ryerson, Miss Emily Borie', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Ryerson, Master John Borie', 'age': 13.0, 'sex': 'male'},
#  {'name': 'Ryerson, Miss Susan (Suzette) Parker',
#   'age': 21.0,
#   'sex': 'female'},
#  {'name': 'Saalfeld, Mr Adolphe', 'age': None, 'sex': 'male'},
#  {'name': 'Salomon, Mr Abraham L', 'age': None, 'sex': 'male'},
#  {'name': 'Schabert, Mrs Paul (Emma Mock)', 'age': None, 'sex': 'female'},
#  {'name': 'Seward, Mr Frederic Kimber', 'age': 34.0, 'sex': 'male'},
#  {'name': 'Shutes, Miss Elizabeth W', 'age': 40.0, 'sex': 'female'},
#  {'name': 'Silverthorne, Mr Spencer Victor', 'age': 36.0, 'sex': 'male'},
#  {'name': 'Silvey, Mr William Baird', 'age': 50.0, 'sex': 'male'},
#  {'name': 'Silvey, Mrs William Baird (Alice Munger)',
#   'age': 39.0,
#   'sex': 'female'},
#  {'name': 'Simonius-Blumer, Col Alfons', 'age': 56.0, 'sex': 'male'},
#  {'name': 'Sloper, Mr William Thompson', 'age': 28.0, 'sex': 'male'},
#  {'name': 'Smart, Mr John Montgomery', 'age': 56.0, 'sex': 'male'},
#  {'name': 'Smith, Mr James Clinch', 'age': 56.0, 'sex': 'male'},
#  {'name': 'Smith, Mr Lucien Philip', 'age': 24.0, 'sex': 'male'},
#  {'name': 'Smith, Mrs Lucien Philip (Mary Eloise Hughes',
#   'age': 18.0,
#   'sex': 'female'},
#  {'name': 'Smith, Mr Richard William', 'age': None, 'sex': 'male'},
#  {'name': 'Snyder, Mr John Pillsbury', 'age': 24.0, 'sex': 'male'},
#  {'name': 'Snyder, Mrs John Pillsbury (Nelle Stevenson)',
#   'age': 23.0,
#   'sex': 'female'},
#  {'name': 'Spedden, Mr Frederick Oakley', 'age': 45.0, 'sex': 'male'},
#  {'name': 'Spedden, Mrs Frederick Oakley (Margaretta Corning Stone)',
#   'age': 40.0,
#   'sex': 'female'},
#  {'name': 'Spedden, Master Robert Douglas', 'age': 6.0, 'sex': 'male'},
#  {'name': 'Spencer, Mr William Augustus', 'age': 57.0, 'sex': 'male'},
#  {'name': 'Spencer, Mrs William Augustus (Marie Eugenie)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Staehlin, Dr Max', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Stead, Mr William Thomas', 'age': 62.0, 'sex': 'male'},
#  {'name': 'Stengel, Mr Charles Emil Henry', 'age': 54.0, 'sex': 'male'},
#  {'name': 'Stengel, Mrs Charles Emil Henry (Annie May Morris)',
#   'age': 43.0,
#   'sex': 'female'},
#  {'name': 'Stephenson, Mrs Walter Bertram (Martha Eustis)',
#   'age': 52.0,
#   'sex': 'female'},
#  {'name': 'Stewart, Mr Albert A', 'age': None, 'sex': 'male'},
#  {'name': 'Stone, Mrs George Nelson (Martha E)', 'age': 62.0, 'sex': 'female'},
#  {'name': 'Straus, Mr Isidor', 'age': 67.0, 'sex': 'male'},
#  {'name': 'Straus, Mrs Isidor (Ida Blun)', 'age': 63.0, 'sex': 'female'},
#  {'name': 'Sutton, Mr Frederick', 'age': 61.0, 'sex': 'male'},
#  {'name': 'Swift, Mrs Frederick Joel (Margaret Welles Barron)',
#   'age': 46.0,
#   'sex': 'female'},
#  {'name': 'Taussig, Mr Emil', 'age': 52.0, 'sex': 'male'},
#  {'name': 'Taussig, Mrs Emil (Tillie Mandelbaum)',
#   'age': 39.0,
#   'sex': 'female'},
#  {'name': 'Taussig, Miss Ruth', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Taylor, Mr Elmer Zebley', 'age': 48.0, 'sex': 'male'},
#  {'name': 'Taylor, Mrs Elmer Zebley (Juliet Cummins Wright)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Thayer, Mr John Borland', 'age': 49.0, 'sex': 'male'},
#  {'name': 'Thayer, Mrs John Borland (Marian Longstreth Morris)',
#   'age': 39.0,
#   'sex': 'female'},
#  {'name': 'Thayer, Mr John Borland, jr', 'age': 17.0, 'sex': 'male'},
#  {'name': 'Thorne, Mr George (alias of: Mr George Rosenshine)',
#   'age': 46.0,
#   'sex': 'male'},
#  {'name': 'Thorne, Mrs Gertrude Maybelle', 'age': None, 'sex': 'female'},
#  {'name': 'Tucker, Mr Gilbert Milligan, jr', 'age': 31.0, 'sex': 'male'},
#  {'name': 'Uruchurtu, Mr Manuel E', 'age': None, 'sex': 'male'},
#  {'name': 'Van Derhoef, Mr Wyckoff', 'age': 61.0, 'sex': 'male'},
#  {'name': 'Walker, Mr William Anderson', 'age': 47.0, 'sex': 'male'},
#  {'name': 'Warren, Mr Frank Manley', 'age': 64.0, 'sex': 'male'},
#  {'name': 'Warren, Mrs Frank Manley (Anna S Atkinson)',
#   'age': 60.0,
#   'sex': 'female'},
#  {'name': 'Weir, Col John', 'age': 60.0, 'sex': 'male'},
#  {'name': 'White, Mrs J Stuart (Ella Holmes)', 'age': 55.0, 'sex': 'female'},
#  {'name': 'White, Mr Percival Wayland', 'age': 54.0, 'sex': 'male'},
#  {'name': 'White, Mr Richard Frasar', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Wick, Mr George Dennick', 'age': 57.0, 'sex': 'male'},
#  {'name': 'Wick, Mrs George Dennick (Martha Hitchcock)',
#   'age': 45.0,
#   'sex': 'female'},
#  {'name': 'Wick, Miss Mary Natalie', 'age': 31.0, 'sex': 'female'},
#  {'name': 'Widener, Mr George Dunton', 'age': 50.0, 'sex': 'male'},
#  {'name': 'Widener, Mrs George Dunton (Eleanor Elkins)',
#   'age': 50.0,
#   'sex': 'female'},
#  {'name': 'Widener, Mr Harry Elkins', 'age': 27.0, 'sex': 'male'},
#  {'name': 'Willard, Miss Constance', 'age': 20.0, 'sex': 'female'},
#  {'name': 'Williams, Mr Charles Duane', 'age': 51.0, 'sex': 'male'},
#  {'name': 'Williams, Mr Fletcher Lambert', 'age': None, 'sex': 'male'},
#  {'name': 'Williams, Mr Richard Norris II', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Woolner, Mr Hugh', 'age': None, 'sex': 'male'},
#  {'name': 'Wright, Mr George', 'age': None, 'sex': 'male'},
#  {'name': 'Young, Miss Marie Grice', 'age': 36.0, 'sex': 'female'},
#  {'name': 'Barber, Ms ', 'age': None, 'sex': 'female'},
#  {'name': 'Bazzani, Ms Albina', 'age': None, 'sex': 'female'},
#  {'name': 'Bidois, Miss Rosalie', 'age': None, 'sex': 'female'},
#  {'name': 'Bird, Ms Ellen', 'age': None, 'sex': 'female'},
#  {'name': 'Bissetti, Ms Amelia', 'age': None, 'sex': 'female'},
#  {'name': 'Burns, Ms Elizabeth Margaret', 'age': None, 'sex': 'female'},
#  {'name': 'Chaudanson, Ms \tVictorine', 'age': None, 'sex': 'female'},
#  {'name': 'Cleaver, Ms Alice', 'age': None, 'sex': 'female'},
#  {'name': 'Daniels, Ms Sarah', 'age': None, 'sex': 'female'},
#  {'name': 'Endres, Miss Caroline Louise', 'age': None, 'sex': 'female'},
#  {'name': 'Farthing, Mr John', 'age': None, 'sex': 'male'},
#  {'name': 'Fleming, Ms Margaret', 'age': None, 'sex': 'female'},
#  {'name': 'Francatelli, Ms Laura Mabel', 'age': None, 'sex': 'female'},
#  {'name': 'Fry, Mr Richard', 'age': None, 'sex': 'male'},
#  {'name': 'Geiger, Miss Emily ', 'age': None, 'sex': 'female'},
#  {'name': 'Giglio, Mr Victor', 'age': None, 'sex': 'male'},
#  {'name': 'Harrington, Mr Charles', 'age': None, 'sex': 'male'},
#  {'name': 'Harrison, Mr William \tHenry', 'age': 40.0, 'sex': 'male'},
#  {'name': 'Hassah, Mr Hamad', 'age': None, 'sex': 'male'},
#  {'name': 'Icabad (Icabod), Ms', 'age': None, 'sex': 'female'},
#  {'name': 'Keeping, Mr Edwin', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Kenchen, Ms Amelia', 'age': None, 'sex': 'female'},
#  {'name': 'LeRoy, Miss Berthe', 'age': None, 'sex': 'female'},
#  {'name': 'Lesneur, Mr Gustave', 'age': None, 'sex': 'male'},
#  {'name': 'Maloney, Ms', 'age': None, 'sex': 'female'},
#  {'name': 'Oliva, Mlle', 'age': None, 'sex': 'female'},
#  {'name': 'Pericault, Ms', 'age': None, 'sex': 'female'},
#  {'name': 'Ringhini, Mr Sante', 'age': 33.0, 'sex': 'male'},
#  {'name': 'Robbins, Mr Victor', 'age': None, 'sex': 'male'},
#  {'name': 'Segesser, Mlle Emma', 'age': None, 'sex': 'female'},
#  {'name': 'Seredeca, Ms', 'age': None, 'sex': 'female'},
#  {'name': 'Ward, Ms Anna', 'age': None, 'sex': 'female'},
#  {'name': 'Wilson, Ms Helen', 'age': None, 'sex': 'female'},
#  {'name': 'Abelson, Mr Samuel', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Abelson, Mrs Samuel (Anna)', 'age': 28.0, 'sex': 'female'},
#  {'name': 'Andrew, Mr Edgar Samuel', 'age': 18.0, 'sex': 'male'},
#  {'name': 'Andrew, Mr Frank', 'age': None, 'sex': 'male'},
#  {'name': 'Angle, Mr William A', 'age': 34.0, 'sex': 'male'},
#  {'name': 'Angle, Mrs William A (Florence)', 'age': 32.0, 'sex': 'female'},
#  {'name': 'Ashby, Mr John', 'age': 57.0, 'sex': 'male'},
#  {'name': 'Bailey, Mr Percy Andrew', 'age': 18.0, 'sex': 'male'},
#  {'name': 'Baimbrigge, Mr Charles R', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Balls, Mrs Ada E Hall', 'age': 36.0, 'sex': 'female'},
#  {'name': 'Banfield, Mr Frederick J', 'age': 28.0, 'sex': 'male'},
#  {'name': 'Bateman, Rev Robert James', 'age': 51.0, 'sex': 'male'},
#  {'name': 'Beane, Mr Edward', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Beane, Mrs Edward (Ethel Clarke)', 'age': 19.0, 'sex': 'female'},
#  {'name': 'Beauchamp, Mr Henry James', 'age': 28.0, 'sex': 'male'},
#  {'name': 'Becker, Mrs Allen Oliver (Nellie E Baumgardner)',
#   'age': 36.0,
#   'sex': 'female'},
#  {'name': 'Becker, Miss Marion Louise', 'age': 4.0, 'sex': 'female'},
#  {'name': 'Becker, Master Richard F', 'age': 1.0, 'sex': 'male'},
#  {'name': 'Becker, Miss Ruth Elizabeth', 'age': 12.0, 'sex': 'female'},
#  {'name': 'Beesley, Mr Lawrence', 'age': 34.0, 'sex': 'male'},
#  {'name': 'Bentham, Miss Lilian W', 'age': 19.0, 'sex': 'female'},
#  {'name': 'Berriman, Mr William S', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Botsford, Mr William Hull', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Bowenur, Mr Solomon', 'age': None, 'sex': 'male'},
#  {'name': 'Bracken, Mr James H', 'age': 27.0, 'sex': 'male'},
#  {'name': 'Brown, Miss Edith E', 'age': 15.0, 'sex': 'female'},
#  {'name': 'Brown, Mr Thomas William Solomon', 'age': 45.0, 'sex': 'male'},
#  {'name': 'Brown, Mrs Thomas William Solomon (Elizabeth C)',
#   'age': 40.0,
#   'sex': 'female'},
#  {'name': 'Bryhl, Miss Dagmar', 'age': 20.0, 'sex': 'female'},
#  {'name': 'Bryhl, Mr Kurt Arnold Gottfrid', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Buss, Miss Kate', 'age': 36.0, 'sex': 'female'},
#  {'name': 'Butler, Mr Reginald Fenton', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Byles, Rev Thomas Roussel D', 'age': None, 'sex': 'male'},
#  {'name': 'Bystrom, Mrs Carolina', 'age': 42.0, 'sex': 'female'},
#  {'name': 'Caldwell, Mr Albert Francis', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Caldwell, Mrs Albert Francis (Sylvia Mae Harbaugh)',
#   'age': 26.0,
#   'sex': 'female'},
#  {'name': 'Caldwell, Master Alden Gates', 'age': 0.83, 'sex': 'male'},
#  {'name': 'Cameron, Miss Clear', 'age': 31.0, 'sex': 'female'},
#  {'name': 'Campbell, Mr William', 'age': None, 'sex': 'male'},
#  {'name': 'Carbines, Mr William', 'age': 19.0, 'sex': 'male'},
#  {'name': 'Carter, Rev Ernest Courtenay', 'age': 54.0, 'sex': 'male'},
#  {'name': 'Carter, Mrs Ernest Courtenay (Lillian Hughes)',
#   'age': 44.0,
#   'sex': 'female'},
#  {'name': 'Chapman, Mr Charles Henry', 'age': 52.0, 'sex': 'male'},
#  {'name': 'Chapman, Mr John Henry', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Chapman, Mrs John Henry (Elizabeth Lawry)',
#   'age': 30.0,
#   'sex': 'female'},
#  {'name': 'Christy, Mrs Alice Frances', 'age': None, 'sex': 'female'},
#  {'name': 'Christy, Miss Julie', 'age': None, 'sex': 'female'},
#  {'name': 'Clarke, Mr Charles V', 'age': 29.0, 'sex': 'male'},
#  {'name': 'Clarke, Mrs Charles V (Ada Maria)', 'age': None, 'sex': 'female'},
#  {'name': 'Coleridge, Mr Reginald Charles', 'age': 29.0, 'sex': 'male'},
#  {'name': 'Collander, Mr Erik', 'age': 27.0, 'sex': 'male'},
#  {'name': 'Collett, Mr Sidney C Stuart', 'age': 24.0, 'sex': 'male'},
#  {'name': 'Collyer, Mr Harvey', 'age': 35.0, 'sex': 'male'},
#  {'name': 'Collyer, Mrs Harvey (Charlotte Tate)',
#   'age': 31.0,
#   'sex': 'female'},
#  {'name': 'Collyer, Miss Marjorie', 'age': 8.0, 'sex': 'female'},
#  {'name': 'Cook, Mrs Selena Rogers', 'age': 22.0, 'sex': 'female'},
#  {'name': 'Corbett, Mrs Walter H (Irene Colvin)',
#   'age': 30.0,
#   'sex': 'female'},
#  {'name': 'Corey, Mrs Percy C (Mary Phyllis Elizabeth Miller)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Cotterill, Mr Harry', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Cunningham, Mr Alfred Fleming', 'age': None, 'sex': 'male'},
#  {'name': 'Davies, Mr Charles Henry', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Davis, Mrs Agnes', 'age': 49.0, 'sex': 'female'},
#  {'name': 'Davis, Master John Morgan', 'age': 8.0, 'sex': 'male'},
#  {'name': 'Davis, Miss Mary', 'age': 28.0, 'sex': 'female'},
#  {'name': 'Deacon, Mr Percy', 'age': 18.0, 'sex': 'male'},
#  {'name': 'de Brito, Mr Jose Joaquim', 'age': None, 'sex': 'male'},
#  {'name': 'del Carlo, Mr Sebastiano', 'age': 28.0, 'sex': 'male'},
#  {'name': 'del Carlo, Mrs Sebastiano (Argenia Genovese)',
#   'age': 22.0,
#   'sex': 'female'},
#  {'name': 'Denbury, Mr Herbert', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Dibden, Mr William', 'age': 18.0, 'sex': 'male'},
#  {'name': 'Doling, Mrs Ada', 'age': 32.0, 'sex': 'female'},
#  {'name': 'Doling, Miss Elsie', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Downton (?Douton), Mr William James', 'age': None, 'sex': 'male'},
#  {'name': 'Drew, Mr James Vivian', 'age': 42.0, 'sex': 'male'},
#  {'name': 'Drew, Mrs James Vivian (Lulu Thorne Christian)',
#   'age': 34.0,
#   'sex': 'female'},
#  {'name': 'Drew, Master Marshall Brines', 'age': 8.0, 'sex': 'male'},
#  {'name': 'Duran y More, Miss Asuncion', 'age': None, 'sex': 'female'},
#  {'name': 'Duran y More, Miss Florentina', 'age': None, 'sex': 'female'},
#  {'name': 'Eitemiller, Mr George Floyd', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Enander, Mr Ingvar', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Fahlstrom, Mr Arne Jonas', 'age': 19.0, 'sex': 'male'},
#  {'name': 'Faunthorpe, Mr Harry', 'age': None, 'sex': 'male'},
#  {'name': 'Faunthorpe, Mrs Lizzie (see Wilkinson, E)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Fillbrook, Mr Charles', 'age': None, 'sex': 'male'},
#  {'name': 'Fox, Mr Stanley H', 'age': 38.0, 'sex': 'male'},
#  {'name': 'Frost, Mr Anthony (Archie) W', 'age': None, 'sex': 'male'},
#  {'name': 'Funk, Miss Annie C', 'age': 38.0, 'sex': 'female'},
#  {'name': 'Fynney, Mr Joseph J', 'age': 35.0, 'sex': 'male'},
#  {'name': 'Gale, Mr Harry', 'age': 35.0, 'sex': 'male'},
#  {'name': 'Gale, Mr Shadrach', 'age': 38.0, 'sex': 'male'},
#  {'name': 'Garside, Miss Ethel', 'age': 24.0, 'sex': 'female'},
#  {'name': 'Gaskell, Mr Alfred', 'age': 16.0, 'sex': 'male'},
#  {'name': 'Gavey, Mr Lawrence', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Gilbert, Mr William', 'age': 45.0, 'sex': 'male'},
#  {'name': 'Giles, Mr Edgar', 'age': 24.0, 'sex': 'male'},
#  {'name': 'Giles, Mr Frederick', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Giles, Mr Ralph', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Gill, Mr John W', 'age': None, 'sex': 'male'},
#  {'name': 'Gillespie, Mr William', 'age': 34.0, 'sex': 'male'},
#  {'name': 'Givard, Mr Hans Christensen', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Greenberg, Mr Samuel', 'age': 50.0, 'sex': 'male'},
#  {'name': 'Hale, Mr Reginald', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Hamalainen, Mrs William (Anna)', 'age': 23.0, 'sex': 'female'},
#  {'name': 'Hamalainen, Master Viljo', 'age': 1.0, 'sex': 'male'},
#  {'name': 'Harbeck, Mr William H', 'age': 44.0, 'sex': 'male'},
#  {'name': 'Harper, Rev John', 'age': 28.0, 'sex': 'male'},
#  {'name': 'Harper, Miss Nina', 'age': 6.0, 'sex': 'female'},
#  {'name': 'Harris, Mr George', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Harris, Mr Walter', 'age': None, 'sex': 'male'},
#  {'name': 'Hart, Mr Benjamin', 'age': 43.0, 'sex': 'male'},
#  {'name': 'Hart, Mrs Benjamin (Esther)', 'age': 45.0, 'sex': 'female'},
#  {'name': 'Hart, Miss Eva Miriam', 'age': 7.0, 'sex': 'female'},
#  {'name': 'Herman, Miss Alice', 'age': 24.0, 'sex': 'female'},
#  {'name': 'Herman, Miss Kate', 'age': 24.0, 'sex': 'female'},
#  {'name': 'Herman, Mr Samuel', 'age': 49.0, 'sex': 'male'},
#  {'name': 'Herman, Mrs Samuel (Jane Laver)', 'age': 48.0, 'sex': 'female'},
#  {'name': 'Hewlett, Mrs Mary D', 'age': None, 'sex': 'female'},
#  {'name': 'Hickman, Mr Leonard Mark', 'age': 34.0, 'sex': 'male'},
#  {'name': 'Hickman, Mr Lewis', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Hickman, Mr Stanley George', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Hiltunen, Miss Marta', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Hocking, Mrs Elizabeth', 'age': 53.0, 'sex': 'female'},
#  {'name': 'Hocking, Mr George', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Hocking, Miss Ellen (Nellie)', 'age': 21.0, 'sex': 'female'},
#  {'name': 'Hocking, Mr Samuel James', 'age': None, 'sex': 'male'},
#  {'name': 'Hodges, Mr Henry Price', 'age': 52.0, 'sex': 'male'},
#  {'name': 'Hold, Mr Stephen', 'age': 42.0, 'sex': 'male'},
#  {'name': 'Hold, Mrs Stephen (Annie Margaret)', 'age': 36.0, 'sex': 'female'},
#  {'name': 'Hood, Mr Ambrose, Jr', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Hosono, Mr Masafumi', 'age': 41.0, 'sex': 'male'},
#  {'name': 'Howard, Mr Benjamin', 'age': None, 'sex': 'male'},
#  {'name': 'Howard, Mrs Benjamin (Ellen Truelove)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Hunt, Mr George Henry', 'age': 33.0, 'sex': 'male'},
#  {'name': 'Ilett, Miss Bertha', 'age': 17.0, 'sex': 'female'},
#  {'name': 'Jacobsohn Mr Sidney Samuel', 'age': None, 'sex': 'male'},
#  {'name': 'Jacobsohn, Mrs Sidney Samuel (Amy Frances Christy)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Jarvis, Mr John Denzil', 'age': None, 'sex': 'male'},
#  {'name': 'Jefferys, Mr Clifford', 'age': None, 'sex': 'male'},
#  {'name': 'Jefferys, Mr Ernest', 'age': None, 'sex': 'male'},
#  {'name': 'Jenkin, Mr Stephen Curnow', 'age': None, 'sex': 'male'},
#  {'name': 'Jerwan, Mrs Amin S (Marie Thuillard)',
#   'age': 23.0,
#   'sex': 'female'},
#  {'name': 'Kantor, Mr Sinai', 'age': 34.0, 'sex': 'male'},
#  {'name': 'Kantor, Mrs Sinai (Miriam Sternim)', 'age': None, 'sex': 'female'},
#  {'name': 'Karnes, Mrs J Frank (Claire Bennett)',
#   'age': 22.0,
#   'sex': 'female'},
#  {'name': 'Keane, Mr Daniel', 'age': None, 'sex': 'male'},
#  {'name': 'Keane, Miss Nora A', 'age': None, 'sex': 'female'},
#  {'name': 'Kelly, Mrs Florence (Fannie)', 'age': 45.0, 'sex': 'female'},
#  {'name': 'Kirkland, Rev Charles Leonard', 'age': None, 'sex': 'male'},
#  {'name': 'Knight, Mr Robert', 'age': None, 'sex': 'male'},
#  {'name': 'Kvillner, Mr Johan Henrik Johannesson', 'age': 31.0, 'sex': 'male'},
#  {'name': 'Lahtinen, Rev William', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Lahtinen, Mrs William (Anna Sylvan)', 'age': 26.0, 'sex': 'female'},
#  {'name': 'Lamb, Mr John James', 'age': None, 'sex': 'male'},
#  {'name': 'Lemore, Mrs Amelia', 'age': 34.0, 'sex': 'female'},
#  {'name': 'LaRoche, Mr Joseph', 'age': 26.0, 'sex': 'male'},
#  {'name': 'LaRoche, Mrs Joseph (Juliet)', 'age': 22.0, 'sex': 'female'},
#  {'name': 'LaRoche, Miss Louise', 'age': 1.0, 'sex': 'female'},
#  {'name': 'LaRoche, Miss Simonne', 'age': 3.0, 'sex': 'female'},
#  {'name': 'Lehmann, Miss Bertha', 'age': None, 'sex': 'female'},
#  {'name': 'Leitch, Miss Jessie', 'age': None, 'sex': 'female'},
#  {'name': 'Levy, Mr Rene Jacques', 'age': None, 'sex': 'male'},
#  {'name': 'Leyson, Mr Robert William Norman', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Lingan, Mr John', 'age': None, 'sex': 'male'},
#  {'name': 'Louch, Mr Charles Alexander', 'age': 48.0, 'sex': 'male'},
#  {'name': 'Louch, Mrs Charles Alexander (Alice Adelaide)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Mack, Mrs Mary', 'age': 57.0, 'sex': 'female'},
#  {'name': 'Malachard, Mr Noel', 'age': None, 'sex': 'male'},
#  {'name': 'Mallet, Mr Albert', 'age': None, 'sex': 'male'},
#  {'name': 'Mallet, Mrs Albert (Antoinette)', 'age': None, 'sex': 'female'},
#  {'name': 'Mallet, Master Andre', 'age': 2.0, 'sex': 'male'},
#  {'name': 'Mangiavacchi, Mr Serafino Emilio', 'age': None, 'sex': 'male'},
#  {'name': 'Mantvila, Rev Joseph', 'age': 27.0, 'sex': 'male'},
#  {'name': 'Marshall, Mrs Kate Louise Phillips', 'age': 19.0, 'sex': 'female'},
#  {'name': 'Matthews, Mr William John', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Maybery, Mr Frank H', 'age': 20.0, 'sex': 'male'},
#  {'name': 'McCrae, Mr Arthur Gordon', 'age': 45.0, 'sex': 'male'},
#  {'name': 'McCrie, Mr James Matthew', 'age': None, 'sex': 'male'},
#  {'name': 'McKane, Mr Peter D', 'age': 46.0, 'sex': 'male'},
#  {'name': 'Mellenger, Mrs Elizabeth Anne', 'age': 41.0, 'sex': 'female'},
#  {'name': 'Mellenger, Miss Madeleine Violet', 'age': 13.0, 'sex': 'female'},
#  {'name': 'Mellor, Mr William John', 'age': 19.0, 'sex': 'male'},
#  {'name': 'Meyer, Mr August', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Milling, Mr Jacob Christian', 'age': 48.0, 'sex': 'male'},
#  {'name': 'Mitchell, Mr Henry Michael', 'age': 71.0, 'sex': 'male'},
#  {'name': 'Moraweck, Dr Ernest', 'age': 54.0, 'sex': 'male'},
#  {'name': 'Morley, Mr William', 'age': None, 'sex': 'male'},
#  {'name': 'Mudd, Mr Thomas C', 'age': None, 'sex': 'male'},
#  {'name': 'Myles, Mr Thomas Francis', 'age': 64.0, 'sex': 'male'},
#  {'name': 'Nasser (Nasrallah), Mr Nicholas', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Nasser (Nasrallah), Mrs Nicholas', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Navratil, Master Edmond Roger', 'age': 2.0, 'sex': 'male'},
#  {'name': 'Navratil, Mr Michel', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Navratil, Master Michel M', 'age': 3.0, 'sex': 'male'},
#  {'name': 'Nesson, Mr Israel', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Nicholls, Mr Joseph Charles', 'age': 19.0, 'sex': 'male'},
#  {'name': 'Norman, Mr Robert Douglas', 'age': None, 'sex': 'male'},
#  {'name': 'Nourney, Mr Alfred (aka Baron von Drachstedt)',
#   'age': 20.0,
#   'sex': 'male'},
#  {'name': 'Nye, Mrs Elizabeth Ramell', 'age': 29.0, 'sex': 'female'},
#  {'name': 'Otter, Mr Richard', 'age': 39.0, 'sex': 'male'},
#  {'name': 'Oxenham, Mr Percy Thomas', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Padro y Manent, Mr Julian', 'age': None, 'sex': 'male'},
#  {'name': 'Pain, Dr Alfred', 'age': 24.0, 'sex': 'male'},
#  {'name': 'Pallas y Castello, Mr Emilio', 'age': None, 'sex': 'male'},
#  {'name': 'Parker, Mr Clifford R', 'age': 28.0, 'sex': 'male'},
#  {'name': 'Parkes, Mr Francis (Frank)', 'age': None, 'sex': 'male'},
#  {'name': 'Parrish, Mrs Lutie Davis', 'age': 50.0, 'sex': 'female'},
#  {'name': 'Pengelly, Mr Frederick', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Peruschitz, Rev Joseph M', 'age': 40.0, 'sex': 'male'},
#  {'name': 'Phillips, Miss Alice', 'age': 42.0, 'sex': 'female'},
#  {'name': 'Phillips, Mr Robert', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Pinsky, Miss Rosa', 'age': 32.0, 'sex': 'female'},
#  {'name': 'Ponesell, Mr Martin', 'age': 34.0, 'sex': 'male'},
#  {'name': 'Portaluppi, Mr Emilio', 'age': None, 'sex': 'male'},
#  {'name': 'Pulbaum, Mr Frank', 'age': None, 'sex': 'male'},
#  {'name': 'Quick, Mrs Frederick C (Jane Richards)',
#   'age': 33.0,
#   'sex': 'female'},
#  {'name': 'Quick, Miss Phyllis May', 'age': 2.0, 'sex': 'female'},
#  {'name': 'Quick, Miss Winifred Vera', 'age': 8.0, 'sex': 'female'},
#  {'name': 'Reeves, Mr David', 'age': 36.0, 'sex': 'male'},
#  {'name': 'Renouf, Mr Peter Henry', 'age': 34.0, 'sex': 'male'},
#  {'name': 'Renouf, Mrs Peter Henry (Lillian Jefferys)',
#   'age': 30.0,
#   'sex': 'female'},
#  {'name': 'Reynaldo, Mrs Encarnacion', 'age': 28.0, 'sex': 'female'},
#  {'name': 'Richard, Mr Emil', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Richards, Master George Sidney', 'age': 0.8, 'sex': 'male'},
#  {'name': 'Richards, Mrs Sidney (Emily Hocking)',
#   'age': 25.0,
#   'sex': 'female'},
#  {'name': 'Richards, Master William Rowe', 'age': 3.0, 'sex': 'male'},
#  {'name': 'Ridsdale, Miss Lucy', 'age': 50.0, 'sex': 'female'},
#  {'name': 'Rogers, Mr Harry', 'age': None, 'sex': 'male'},
#  {'name': 'Rugg, Miss Emily', 'age': 21.0, 'sex': 'female'},
#  {'name': 'Sedgwick, Mr Charles Frederick Waddington',
#   'age': None,
#   'sex': 'male'},
#  {'name': 'Sharp, Mr Percival', 'age': None, 'sex': 'male'},
#  {'name': 'Shelley, Mrs William (Imanita)', 'age': 25.0, 'sex': 'female'},
#  {'name': 'Silven, Miss Lyyli', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Sincock, Miss Maude', 'age': 20.0, 'sex': 'female'},
#  {'name': 'Siukonnen, Miss Anna', 'age': 30.0, 'sex': 'female'},
#  {'name': 'Sjostedt, Mr Ernst Adolf', 'age': 59.0, 'sex': 'male'},
#  {'name': 'Slayter, Miss Hilda Mary', 'age': 30.0, 'sex': 'female'},
#  {'name': 'Slemen, Mr Richard James', 'age': 35.0, 'sex': 'male'},
#  {'name': 'Smith (Schmidt), Mr Augustus', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Smith, Miss Marion', 'age': None, 'sex': 'female'},
#  {'name': 'Sobey, Mr Hayden', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Stanton, Mr Samuel Ward', 'age': 41.0, 'sex': 'male'},
#  {'name': 'Stokes, Mr Philip Joseph', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Sweet, Mr George', 'age': 14.0, 'sex': 'male'},
#  {'name': 'Toomey, Miss Ellen', 'age': 50.0, 'sex': 'female'},
#  {'name': 'Troupiansky, Mr Moses Aaron', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Trout, Mrs William H (Jessie L)', 'age': None, 'sex': 'female'},
#  {'name': 'Troutt, Miss Edwina Celia', 'age': 27.0, 'sex': 'female'},
#  {'name': 'Turpin, Mr William John', 'age': 29.0, 'sex': 'male'},
#  {'name': 'Turpin, Mrs William John (Dorothy Anne Wonnacott)',
#   'age': 27.0,
#   'sex': 'female'},
#  {'name': 'Veale, Mr James', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Waelens, Mr Achille', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Walcroft, Miss Nellie', 'age': 35.0, 'sex': 'female'},
#  {'name': 'Ware, Mr John James', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Ware, Mrs John James (Florence Louise Long)',
#   'age': 28.0,
#   'sex': 'female'},
#  {'name': 'Ware, Mr William J', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Watson, Mr Ennis Hastings', 'age': None, 'sex': 'male'},
#  {'name': 'Watt, Miss Bertha', 'age': 12.0, 'sex': 'female'},
#  {'name': 'Watt, Mrs James (Bessie Inglis Milne)',
#   'age': 40.0,
#   'sex': 'female'},
#  {'name': 'Webber, Miss Susan', 'age': 36.0, 'sex': 'female'},
#  {'name': 'Weisz, Mr Leopold', 'age': 28.0, 'sex': 'male'},
#  {'name': 'Weisz, Mrs Leopold (Mathilde)', 'age': 32.0, 'sex': 'female'},
#  {'name': 'Wells, Mrs Arthur H (Addie Trevaskis)',
#   'age': 29.0,
#   'sex': 'female'},
#  {'name': 'Wells, Miss Joan', 'age': 4.0, 'sex': 'female'},
#  {'name': 'Wells, Master Ralph Lester', 'age': 2.0, 'sex': 'male'},
#  {'name': 'West, Miss Barbara J', 'age': None, 'sex': 'female'},
#  {'name': 'West, Miss Constance Mirium', 'age': None, 'sex': 'female'},
#  {'name': 'West, Mr Edwy Arthur', 'age': 36.0, 'sex': 'male'},
#  {'name': 'West, Mrs Edwy Arthur (Ada Mary)', 'age': 33.0, 'sex': 'female'},
#  {'name': 'Wheadon, Mr Edward', 'age': None, 'sex': 'male'},
#  {'name': 'Wheeler, Mr Edwin', 'age': None, 'sex': 'male'},
#  {'name': 'Wheeler, Mr Frederick', 'age': None, 'sex': 'male'},
#  {'name': 'Wilhelms, Mr Charles', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Wilkinson, Mrs Elizabeth Anne', 'age': None, 'sex': 'female'},
#  {'name': 'Williams, Mr Charles Eugene', 'age': None, 'sex': 'male'},
#  {'name': 'Wright, Miss Marion', 'age': 26.0, 'sex': 'female'},
#  {'name': 'Yrois, Miss Henriette', 'age': None, 'sex': 'female'},
#  {'name': 'Aldworth, Mr Charles Augustus', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Brown, Miss Mildred', 'age': 24.0, 'sex': 'female'},
#  {'name': 'Pernot, Mr Rene', 'age': None, 'sex': 'male'},
#  {'name': 'Swane, Mr George', 'age': 18.0, 'sex': 'male'},
#  {'name': 'Abbing, Mr Anthony', 'age': 42.0, 'sex': 'male'},
#  {'name': 'Abbott, Master Eugene Joseph', 'age': 13.0, 'sex': 'male'},
#  {'name': 'Abbott, Mr Rossmore Edward', 'age': 16.0, 'sex': 'male'},
#  {'name': 'Abbott, Mrs Stanton (Rosa)', 'age': 35.0, 'sex': 'female'},
#  {'name': 'Abelseth, Miss Anna Karen', 'age': 16.0, 'sex': 'female'},
#  {'name': 'Abelseth, Mr Olaus', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Abraham, Mrs Joseph (Sophie Easu)', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Abrahamsson, Mr August', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Adahl, Mr Mauritz Nils Martin', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Adams, Mr John', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Ahlin, Mrs Johanna Persdotter', 'age': 40.0, 'sex': 'female'},
#  {'name': 'Ahmed, Mr Ali', 'age': 24.0, 'sex': 'male'},
#  {'name': 'Aijo-Nirva, Mr Isak', 'age': 41.0, 'sex': 'male'},
#  {'name': 'Aks, Mrs Sam (Leah Rosen)', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Aks, Master Philip', 'age': 0.83, 'sex': 'male'},
#  {'name': 'Alexander, Mr William', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Alhomaki, Mr Ilmari Rudolf', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Ali, Mr William', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Allen, Mr William Henry', 'age': 35.0, 'sex': 'male'},
#  {'name': 'Allum, Mr Owen George', 'age': 17.0, 'sex': 'male'},
#  {'name': 'Andersen, Mr Albert Karvin', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Andersen, Mr Thor Olsvigen', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Andersson, Mr Anders Johan', 'age': 39.0, 'sex': 'male'},
#  {'name': 'Andersson, Mrs Anders Johan (Alfrida K Brogren)',
#   'age': 39.0,
#   'sex': 'female'},
#  {'name': 'Andersson, Miss Ebba Iris', 'age': 6.0, 'sex': 'female'},
#  {'name': 'Andersson, Miss Ellis Anna Maria', 'age': 2.0, 'sex': 'female'},
#  {'name': 'Andersson, Miss Erna', 'age': 17.0, 'sex': 'female'},
#  {'name': 'Andersson, Miss Ida Augusta Margareta',
#   'age': 38.0,
#   'sex': 'female'},
#  {'name': 'Andersson, Miss Ingeborg Constancia', 'age': 9.0, 'sex': 'female'},
#  {'name': 'Andersson, Mr Johan Samuel', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Andersson, Miss Sigrid Elizabeth', 'age': 11.0, 'sex': 'female'},
#  {'name': 'Andersson, Master Sigvard Harald Elias', 'age': 4.0, 'sex': 'male'},
#  {'name': 'Andreasson, Mr Paul Edvin', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Angheloff, Mr Minko', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Arnold, Mr Josef', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Arnold, Mrs Josef (Josephine Frank)', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Aronsson, Mr Ernst Axel Algot', 'age': 24.0, 'sex': 'male'},
#  {'name': 'Asim, Mr Adola', 'age': 35.0, 'sex': 'male'},
#  {'name': 'Asplund, Mr Carl Oscar Vilhelm Gustafsson',
#   'age': 40.0,
#   'sex': 'male'},
#  {'name': 'Asplund, Mrs Carl Oscar (Selma Augusta Johansson)',
#   'age': 38.0,
#   'sex': 'female'},
#  {'name': 'Asplund, Master Carl Edgar', 'age': 5.0, 'sex': 'male'},
#  {'name': 'Asplund, Master Clarence Gustaf Hugo', 'age': 9.0, 'sex': 'male'},
#  {'name': 'Aspland, Master Edvin Rojj Felix', 'age': 3.0, 'sex': 'male'},
#  {'name': 'Asplund, Master Filip Oscar', 'age': 13.0, 'sex': 'male'},
#  {'name': 'Asplund, Mr John Charles', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Asplund, Miss Lillian Gertrud', 'age': 5.0, 'sex': 'female'},
#  {'name': 'Assaf, Mr Gerios', 'age': None, 'sex': 'male'},
#  {'name': 'Assaf, Mrs Mariana', 'age': 45.0, 'sex': 'female'},
#  {'name': 'Assam, Mr Ali', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Attalah, Miss Malaka', 'age': 17.0, 'sex': 'female'},
#  {'name': 'Attala (Kalil), Mr Solomon', 'age': 27.0, 'sex': 'male'},
#  {'name': 'Augustsson, Mr Albert', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Baccos, Mr Rafoul', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Backstrom, Mr Karl Alfred', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Backstrom, Mrs Karl Alfred (Maria Mathilda Gustafsson)',
#   'age': 33.0,
#   'sex': 'female'},
#  {'name': 'Baclini, Miss Eugenie', 'age': 3.0, 'sex': 'female'},
#  {'name': 'Baclini, Miss Helene', 'age': None, 'sex': 'female'},
#  {'name': 'Baclini, Miss Maria', 'age': None, 'sex': 'female'},
#  {'name': 'Baclini, Mrs Solomon (Latifa)', 'age': None, 'sex': 'female'},
#  {'name': 'Badman, Miss Emily Louisa', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Badt, Mr Mohamed', 'age': 40.0, 'sex': 'male'},
#  {'name': 'Balkic, Mr Cerin', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Banoura, Miss Ayout', 'age': 15.0, 'sex': 'female'},
#  {'name': 'Barbara, Mrs Catherine', 'age': 45.0, 'sex': 'female'},
#  {'name': 'Barbara, Miss Saude', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Barry, Miss Julia', 'age': 27.0, 'sex': 'female'},
#  {'name': 'Barton, Mr David', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Beavan, Mr William Thomas', 'age': 19.0, 'sex': 'male'},
#  {'name': 'Bengtsson, Mr John Viktor', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Berglund, Mr Karl Ivar Sven', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Betros, Mr Tannous', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Bing, Mr Lee', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Birkeland, Mr Hans', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Bjorklund, Ernst Herbert', 'age': 18.0, 'sex': 'male'},
#  {'name': 'Bostandyeff, Mr Guentcho', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Boulos, Master Akar', 'age': 6.0, 'sex': 'male'},
#  {'name': 'Boulos, Mr Hanna', 'age': None, 'sex': 'male'},
#  {'name': 'Boulos, Mrs Joseph (Sultana)', 'age': None, 'sex': 'female'},
# ...
#  {'name': 'Davies, Mr Alfred', 'age': 24.0, 'sex': 'male'},
#  {'name': 'Davies, Mr Evan', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Davies, Mr John', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Davies, Mr Joseph', 'age': 17.0, 'sex': 'male'},
#  {'name': 'Davison, Mr Thomas Henry', 'age': None, 'sex': 'male'},
#  {'name': 'Davison, Mrs Thomas Henry (Mary Finck)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Dean, Mr Bertram', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Dean, Mrs Bertram (Eva)', 'age': 33.0, 'sex': 'female'},
#  {'name': 'Dean, Master Bertram Vere', 'age': 1.0, 'sex': 'male'},
#  {'name': 'Dean, Miss Elizabeth Gladys (Millvena)',
#   'age': 0.17,
#   'sex': 'female'},
#  {'name': 'Delalic, Mr Regyo', 'age': 25.0, 'sex': 'male'},
#  {'name': 'De Messemaeker, Mr William Joseph', 'age': 36.0, 'sex': 'male'},
#  {'name': 'De Messemaeker, Mrs William Joseph (Anna)',
#   'age': 36.0,
#   'sex': 'female'},
#  {'name': 'De Mulder, Mr Theo', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Denkoff, Mr Mito', 'age': None, 'sex': 'male'},
#  {'name': 'Dennis, Mr Samuel', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Dennis, Mr William', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Devaney, Miss Margaret', 'age': 19.0, 'sex': 'female'},
#  {'name': 'Dewan, Mr Frank', 'age': 65.0, 'sex': 'male'},
#  {'name': 'Dibo, Mr Elias', 'age': None, 'sex': 'male'},
#  {'name': 'Dimic, Mr Jovan', 'age': 42.0, 'sex': 'male'},
#  {'name': 'Dintcheff, Mr Valtcho', 'age': 43.0, 'sex': 'male'},
#  {'name': 'Dooley, Mr Patrick', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Dorkings, Mr Edward Arthur', 'age': 19.0, 'sex': 'male'},
#  {'name': 'Dowdell, Miss Elizabeth', 'age': 30.0, 'sex': 'female'},
#  {'name': 'Doyle, Miss Elizabeth', 'age': 24.0, 'sex': 'female'},
#  {'name': 'Drapkin, Miss Jennie', 'age': 23.0, 'sex': 'female'},
#  {'name': 'Drazonovic, Mr Josef', 'age': None, 'sex': 'male'},
#  {'name': 'Driscoll, Miss Bridget', 'age': 24.0, 'sex': 'female'},
#  {'name': 'Duquemin, Mr Joseph', 'age': 24.0, 'sex': 'male'},
#  {'name': 'Dyker, Mr Adolf Fredrik', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Dyker, Mrs Adolf Fredrik (Anna Elizabeth Judith Andersson)',
#   'age': 22.0,
#   'sex': 'female'},
#  {'name': 'Econovic, Mr Joso', 'age': None, 'sex': 'male'},
#  {'name': 'Edvardsson, Mr Gustaf Hjalmar', 'age': 18.0, 'sex': 'male'},
#  {'name': 'Eklund, Mr Hans Linus', 'age': 16.0, 'sex': 'male'},
#  {'name': 'Ekstrom, Mr Johan', 'age': 45.0, 'sex': 'male'},
#  {'name': 'Elias, Mr Elias', 'age': None, 'sex': 'male'},
#  {'name': 'Elias, Mr John', 'age': None, 'sex': 'male'},
#  {'name': 'Elias, Mr Joseph', 'age': None, 'sex': 'male'},
#  {'name': 'Elsbury, Mr James', 'age': 47.0, 'sex': 'male'},
#  {'name': 'Emanuel, Miss Virginia Ethel', 'age': 5.0, 'sex': 'female'},
#  {'name': 'Emmeth, Mr Thomas', 'age': None, 'sex': 'male'},
#  {'name': 'Everett, Thomas James', 'age': None, 'sex': 'male'},
#  {'name': 'Farrell, Mr James', 'age': None, 'sex': 'male'},
#  {'name': 'Finoli, Mr Luigi', 'age': None, 'sex': 'male'},
#  {'name': 'Fischer, Mr Eberhard Telander', 'age': None, 'sex': 'male'},
#  {'name': 'Flynn, Mr James', 'age': None, 'sex': 'male'},
#  {'name': 'Flynn, Mr John', 'age': None, 'sex': 'male'},
#  {'name': 'Foley, Mr Joseph', 'age': None, 'sex': 'male'},
#  {'name': 'Foley, Mr William', 'age': None, 'sex': 'male'},
#  {'name': 'Foo, Mr Choong', 'age': None, 'sex': 'male'},
#  {'name': 'Ford, Mr Arthur', 'age': None, 'sex': 'male'},
#  {'name': 'Ford, Miss Doolina Margaret', 'age': 21.0, 'sex': 'female'},
#  {'name': 'Ford, Mr Edward Watson', 'age': 18.0, 'sex': 'male'},
#  {'name': 'Ford, Miss Maggie', 'age': 9.0, 'sex': 'female'},
#  {'name': 'Ford, Mrs Edward (Margaret Ann)', 'age': 48.0, 'sex': 'female'},
#  {'name': 'Ford, Mr Neil Watson', 'age': 16.0, 'sex': 'male'},
#  {'name': 'Fox, Mr Patrick', 'age': None, 'sex': 'male'},
#  {'name': 'Franklin, Mr Charles', 'age': None, 'sex': 'male'},
#  {'name': 'Gallagher, Mr Martin', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Garfirth, Mr John', 'age': None, 'sex': 'male'},
#  {'name': 'Georges, Mrs Shahini Weappi', 'age': 38.0, 'sex': 'female'},
#  {'name': 'Gilinski, Mr Leslie', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Gilnagh, Miss Katie', 'age': 16.0, 'sex': 'female'},
#  {'name': 'Glynn, Miss Mary Agatha', 'age': None, 'sex': 'female'},
#  {'name': 'Goldsmith, Mr Frank John', 'age': 33.0, 'sex': 'male'},
#  {'name': 'Goldsmith, Mrs Frank John (Emily A Brown)',
#   'age': None,
#   'sex': 'female'},
#  {'name': 'Goldsmith, Master Frank John William', 'age': 9.0, 'sex': 'male'},
#  {'name': 'Goldsmith, Mr Nathan', 'age': 41.0, 'sex': 'male'},
#  {'name': 'Goncalves, Mr Manuel Estanslas', 'age': 38.0, 'sex': 'male'},
#  {'name': 'Goodwin, Mr Frederick', 'age': 40.0, 'sex': 'male'},
#  {'name': 'Goodwin, Mrs Frederick (Augusta)', 'age': 43.0, 'sex': 'female'},
#  {'name': 'Goodwin, Mr Charles E', 'age': 14.0, 'sex': 'male'},
#  {'name': 'Goodwin, Miss Lillian A', 'age': 16.0, 'sex': 'female'},
#  {'name': 'Goodwin, Master Harold V', 'age': 9.0, 'sex': 'male'},
#  {'name': 'Goodwin, Miss Jessie A', 'age': 10.0, 'sex': 'female'},
#  {'name': 'Goodwin, Master Sidney L', 'age': 6.0, 'sex': 'male'},
#  {'name': 'Goodwin, Master William F', 'age': 11.0, 'sex': 'male'},
#  {'name': 'Green, Mr George', 'age': 40.0, 'sex': 'male'},
#  {'name': 'Gronnestad, Mr Daniel Danielsen', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Guest, Mr Robert', 'age': None, 'sex': 'male'},
#  {'name': 'Gustafsson, Mr Alfred Ossian', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Gustafsson, Mr Anders Vilhelm', 'age': 37.0, 'sex': 'male'},
#  {'name': 'Gustafsson, Mr Johan Birger', 'age': 28.0, 'sex': 'male'},
#  {'name': 'Gustafsson, Mr Karl Gideon', 'age': 19.0, 'sex': 'male'},
#  {'name': 'Haas, Miss Aloisia', 'age': 24.0, 'sex': 'female'},
#  {'name': 'Hagardon, Miss Kate', 'age': 17.0, 'sex': 'female'},
#  {'name': 'Hagland, Mr Ingvald Olsen', 'age': None, 'sex': 'male'},
#  {'name': 'Hagland, Mr Konrad Mathias Reiersen', 'age': None, 'sex': 'male'},
#  {'name': 'Hakkarainen, Mr Pekko Pietari', 'age': 28.0, 'sex': 'male'},
#  {'name': 'Hakkarainen, Mrs Pekko Pietari', 'age': 24.0, 'sex': 'female'},
#  {'name': 'Hampe, Mr Leon', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Hansen, Mr Claus Peter', 'age': 41.0, 'sex': 'male'},
#  {'name': 'Hansen, Mrs Claus Peter', 'age': 45.0, 'sex': 'female'},
#  {'name': 'Hansen, Mr Henrik Juul', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Hansen, Mr Henry Damsgaard', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Harknett, Miss Alice', 'age': None, 'sex': 'female'},
#  {'name': 'Harmer, Mr Abraham', 'age': None, 'sex': 'male'},
#  {'name': 'Hart, Mr Henry', 'age': None, 'sex': 'male'},
#  {'name': 'Hassan, Mr M Houssein', 'age': None, 'sex': 'male'},
#  {'name': 'Healy, Miss Nora', 'age': None, 'sex': 'female'},
#  {'name': 'Hedman, Mr Oscar', 'age': 27.0, 'sex': 'male'},
#  {'name': 'Hee, Mr Ling', 'age': None, 'sex': 'male'},
#  {'name': 'Hegarty, Miss Nora', 'age': 18.0, 'sex': 'female'},
#  {'name': 'Heikkinen, Miss Laina', 'age': 26.0, 'sex': 'female'},
#  {'name': 'Heininen, Miss Wendla Maria', 'age': 23.0, 'sex': 'female'},
#  {'name': 'Hellstrom, Hilda Maria', 'age': 22.0, 'sex': 'female'},
#  {'name': 'Hemming, Miss Nora', 'age': None, 'sex': 'female'},
#  {'name': 'Hendekovic, Mr Ignaz', 'age': None, 'sex': 'male'},
#  {'name': 'Henery, Delia', 'age': None, 'sex': 'female'},
#  {'name': 'Henriksson, Jenny Lovisa', 'age': 28.0, 'sex': 'female'},
#  {'name': 'Hirvonen, Mrs Alexander', 'age': 22.0, 'sex': 'female'},
#  {'name': 'Hirvonen, Miss Hildur E', 'age': 2.0, 'sex': 'female'},
#  {'name': 'Holm, Mr John Frederik Alexander', 'age': 43.0, 'sex': 'male'},
#  {'name': 'Holthen, Mr Johan Martin', 'age': None, 'sex': 'male'},
#  {'name': 'Honkanen, Miss Eluna', 'age': 27.0, 'sex': 'female'},
#  {'name': 'Horgan, Mr John', 'age': None, 'sex': 'male'},
#  {'name': 'Howard, Miss May', 'age': None, 'sex': 'female'},
#  {'name': 'Humblin, Mr Adolf Mathias Nicolai Olsen',
#   'age': 42.0,
#   'sex': 'male'},
#  {'name': 'Hyman, Mr Abraham', 'age': None, 'sex': 'male'},
#  {'name': 'Ilieff, Mr Ylio', 'age': None, 'sex': 'male'},
#  {'name': 'Ilmakangas, Miss Ida Livija', 'age': 27.0, 'sex': 'female'},
#  {'name': 'Ilmakangas, Miss Pieta Sofia', 'age': 25.0, 'sex': 'female'},
#  {'name': 'Ivanoff, Mr Konio', 'age': None, 'sex': 'male'},
#  {'name': 'Jansen, Mr Carl Olof', 'age': 27.0, 'sex': 'male'},
#  {'name': 'Jardin, Mr Jose Netto', 'age': None, 'sex': 'male'},
#  {'name': 'Jensen, Miss Carla Christine', 'age': 19.0, 'sex': 'female'},
#  {'name': 'Jensen, Mr Hans Peder', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Jensen, Mr Niels Peder', 'age': 48.0, 'sex': 'male'},
#  {'name': 'Jensen, Mr Svend Lauritz', 'age': 17.0, 'sex': 'male'},
#  {'name': 'Jermyn, Miss Annie', 'age': None, 'sex': 'female'},
#  {'name': 'Johannesen-Bratthammer, Mr Bernt', 'age': None, 'sex': 'male'},
#  {'name': 'Johanson, Mr Jakob Alfred', 'age': 34.0, 'sex': 'male'},
#  {'name': 'Johansson, Mr Erik', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Johansson, Mr Gustaff Joel', 'age': 33.0, 'sex': 'male'},
#  {'name': 'Johansson, Mr Karl Johan', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Johansson, Mr Nils', 'age': 29.0, 'sex': 'male'},
#  {'name': 'Johansson, Oscar L', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Johnson, Mr Alfred', 'age': 49.0, 'sex': 'male'},
#  {'name': 'Johnson, Miss Eleanor Ileen', 'age': 1.0, 'sex': 'female'},
#  {'name': 'Johnson, Mr Malkolm Joackim', 'age': 33.0, 'sex': 'male'},
#  {'name': 'Johnson, Master Harold Theodor', 'age': 4.0, 'sex': 'male'},
#  {'name': 'Johnson, Mrs Oscar W', 'age': 24.0, 'sex': 'female'},
#  {'name': 'Johnson, Mr William Cahoone Jr', 'age': 19.0, 'sex': 'male'},
#  {'name': 'Johnston, Mr Andrew G', 'age': None, 'sex': 'male'},
#  {'name': 'Johnston, Mrs Andrew G', 'age': None, 'sex': 'female'},
#  {'name': 'Johnston, Miss Catherine H', 'age': None, 'sex': 'female'},
#  {'name': 'Johnston, Master William A', 'age': None, 'sex': 'male'},
#  {'name': 'Jonkoff, Mr Lazor', 'age': None, 'sex': 'male'},
#  {'name': 'Jonsson, Mr Carl', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Jonsson, Nils Hilding', 'age': 27.0, 'sex': 'male'},
#  {'name': 'Jussila, Miss Aina Maria', 'age': 21.0, 'sex': 'female'},
#  {'name': 'Jussila, Mr Erik', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Jussila, Miss Katriina', 'age': 20.0, 'sex': 'female'},
#  {'name': 'Kallio, Mr Nikolai Erland', 'age': 17.0, 'sex': 'male'},
#  {'name': 'Kalvig, Mr Johannes K Halverson', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Karajic, Mr Milan', 'age': 30.0, 'sex': 'male'},
#  {'name': 'Karlsson, Mr Einar Gervasius', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Karlsson, Mr Julius Konrad Eugen', 'age': 23.0, 'sex': 'male'},
#  {'name': 'Karlsson, Mr Nils August', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Karun, Miss Anna Mary', 'age': 4.0, 'sex': 'female'},
#  {'name': 'Karun, Mr Franz', 'age': 39.0, 'sex': 'male'},
#  {'name': 'Kassem, Mr Fared', 'age': None, 'sex': 'male'},
#  {'name': 'Keane, Mr Andrew', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Keefe, Mr Arthur', 'age': None, 'sex': 'male'},
#  {'name': 'Kekic, Mr Tido', 'age': None, 'sex': 'male'},
#  {'name': 'Kelly, Miss Anna Kate', 'age': 21.0, 'sex': 'female'},
#  {'name': 'Kelly, Mr James', 'age': 44.0, 'sex': 'male'},
#  {'name': 'Kelly, Mr James', 'age': 42.0, 'sex': 'male'},
#  {'name': 'Kelly, Miss Mary', 'age': 21.0, 'sex': 'female'},
#  {'name': 'Kennedy, Mr John', 'age': 24.0, 'sex': 'male'},
#  {'name': 'Khalil, Mr Betros', 'age': None, 'sex': 'male'},
#  {'name': 'Khalil, Mrs Betros', 'age': None, 'sex': 'female'},
#  {'name': 'Khalil, Mr Saad', 'age': None, 'sex': 'male'},
#  {'name': 'Kiernan, Mr John', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Kiernan, Mr Philip', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Kilgannon, Mr Thomas', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Kink, Mr Anton', 'age': 39.0, 'sex': 'male'},
#  {'name': 'Kink, Mrs Anton (Louise Heilmann)', 'age': 26.0, 'sex': 'female'},
#  {'name': 'Kink, Miss Louise Gretchen', 'age': 4.0, 'sex': 'female'},
#  {'name': 'Kink, Miss Maria', 'age': 22.0, 'sex': 'female'},
#  {'name': 'Kink, Mr Vincenz', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Klasen, Miss Gertrud Emilia', 'age': 1.5, 'sex': 'female'},
#  {'name': 'Klasen, Mrs Hulda Kristina', 'age': 36.0, 'sex': 'female'},
#  {'name': 'Klasen, Mr Klas Albin', 'age': 18.0, 'sex': 'male'},
#  {'name': 'Kraeff, Mr Theodor', 'age': None, 'sex': 'male'},
#  {'name': 'Krekorian, Mr Neshan', 'age': 25.0, 'sex': 'male'},
#  {'name': 'Lahowd, Mr Sarkis', 'age': None, 'sex': 'male'},
#  {'name': 'Laitinen, Miss Kritina Sofia', 'age': 37.0, 'sex': 'female'},
#  {'name': 'Laleff, Mr Kristo', 'age': None, 'sex': 'male'},
#  {'name': 'Lam, Mr Ali', 'age': None, 'sex': 'male'},
#  {'name': 'Lam, Mr Len', 'age': None, 'sex': 'male'},
#  {'name': 'Landegren, Miss Aurora Adelia', 'age': 22.0, 'sex': 'female'},
#  {'name': 'Lane, Mr Patrick', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Lang, Mr Fang', 'age': 26.0, 'sex': 'male'},
#  {'name': 'Larsson, Mr August Viktor', 'age': 29.0, 'sex': 'male'},
#  {'name': 'Larsson, Mr Bengt Edvin', 'age': 29.0, 'sex': 'male'},
#  {'name': 'Larsson-Rondberg, Mr Edvard', 'age': 22.0, 'sex': 'male'},
#  {'name': 'Leeni, Mr Fahim', 'age': None, 'sex': 'male'},
#  {'name': 'Lefebre, Mrs Frank', 'age': None, 'sex': 'female'},
#  {'name': 'Lefebre, Master Henry', 'age': None, 'sex': 'male'},
#  {'name': 'Lefebre, Miss Ida', 'age': None, 'sex': 'female'},
#  {'name': 'Lefebre, Miss Jeannie', 'age': None, 'sex': 'female'},
#  {'name': 'Lefebre, Miss Mathilde', 'age': None, 'sex': 'female'},
#  {'name': 'Leinonen, Mr Antti Gustaf', 'age': 32.0, 'sex': 'male'},
#  {'name': 'Lemberopolous, Mr Peter L', 'age': None, 'sex': 'male'},
#  {'name': 'Lemom, Mr Denis', 'age': 21.0, 'sex': 'male'},
#  {'name': 'Lemon, Miss Mary', 'age': 21.0, 'sex': 'female'},
#  {'name': 'Leonard, Mr Lionel', 'age': 36.0, 'sex': 'male'},
#  {'name': 'Lester, Mr James', 'age': 39.0, 'sex': 'male'},
#  {'name': 'Lindahl, Miss Agda V', 'age': 25.0, 'sex': 'female'},
#  {'name': 'Lindblom, Miss Augusta Charlotta', 'age': 45.0, 'sex': 'female'},
#  {'name': 'Lindell, Mr Edvard Bengtsson', 'age': 36.0, 'sex': 'male'},
#  {'name': 'Lindell, Mrs Edvard Bengtsson', 'age': 30.0, 'sex': 'female'},
#  {'name': 'Lindqvist, Eino William', 'age': 20.0, 'sex': 'male'},
#  {'name': 'Linehan, Mr Michael', 'age': None, 'sex': 'male'},
#  {'name': 'Ling, Mr Lee', 'age': None, 'sex': 'male'},
#  {'name': 'Lithman, Mr Simon', 'age': None, 'sex': 'male'},
#  {'name': 'Lobb, Mr William Arthur', 'age': None, 'sex': 'male'},
#  {'name': 'Lobb, Mrs William Arthur', 'age': None, 'sex': 'female'},
#  {'name': 'Lockyer, Mr Edward', 'age': None, 'sex': 'male'},
#  {'name': 'Lovell, Mr John', 'age': None, 'sex': 'male'},
#  {'name': 'Lulich, Mr Nicola', 'age': None, 'sex': 'male'},
#  {'name': 'Lundahl, Mr Johan', 'age': None, 'sex': 'male'},
#  {'name': 'Lundin, Miss Olga Elida', 'age': None, 'sex': 'female'},
#  {'name': 'Lundstrom, Mr Thure Edvin', 'age': None, 'sex': 'male'},
#  {'name': 'Lyntakoff, Mr Stanko', 'age': None, 'sex': 'male'},
#  {'name': 'MacKay, Mr George William', 'age': None, 'sex': 'male'},
#  {'name': 'Madigan, Miss Margaret', 'age': None, 'sex': 'female'},
#  {'name': 'Madsen, Mr Frithiof', 'age': None, 'sex': 'male'},
#  {'name': 'Maenpaa, Mr Matti Alexanteri', 'age': None, 'sex': 'male'},
#  {'name': 'Mahon, Miss Delia', 'age': None, 'sex': 'female'},
#  {'name': 'Maisner, Mr Simon', 'age': None, 'sex': 'male'},
#  {'name': 'Makinen, Mr Kalle Edvard', 'age': None, 'sex': 'male'},
#  {'name': 'Mamee, Mr Hanna', 'age': None, 'sex': 'male'},
#  {'name': 'Mangan, Miss Mary', 'age': None, 'sex': 'female'},
#  {'name': 'Mannion, Miss Margareth', 'age': None, 'sex': 'female'},
#  {'name': 'Mansour, Mr Hanna', 'age': None, 'sex': 'male'},
#  {'name': 'Mardirosian, Mr Sarkis', 'age': None, 'sex': 'male'},
#  {'name': 'Marinko, Mr Dmitri', 'age': None, 'sex': 'male'},
#  {'name': 'Markim, Mr Johann', 'age': None, 'sex': 'male'},
#  {'name': 'Markoff, Mr Marin', 'age': None, 'sex': 'male'},
#  {'name': 'Masselmany, Mrs Fatima', 'age': None, 'sex': 'female'},
#  {'name': 'Matinoff, Mr Nicola', 'age': None, 'sex': 'male'},
#  {'name': 'McCarthy, Miss Katie', 'age': None, 'sex': 'female'},
#  {'name': 'McCormack, Mr Thomas J', 'age': None, 'sex': 'male'},
#  ...]
